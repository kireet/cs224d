# %% [markdown]
# # CS 224D Assignment #2
# # Part [1]: Deep Networks: NER Window Model
#
# For this first part of the assignment, you'll build your first "deep" networks. On problem set 1, you computed the backpropagation gradient $\frac{\partial J}{\partial w}$ for a two-layer network; in this problem set you'll implement a slightly more complex network to perform  named entity recognition (NER).
#
# Before beginning the programming section, you should complete parts (a) and (b) of the corresponding section of the handout.

# %%
import sys, os
from numpy import *
from matplotlib.pyplot import *
# %matplotlib inline
matplotlib.rcParams['savefig.dpi'] = 100

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## (c): Random Initialization Test
# Use the cell below to test your code.

# %%
from misc import random_weight_matrix
random.seed(10)
print random_weight_matrix(3,5)
# Out:
# [[ 0.46994114 -0.83008197  0.23148553  0.43094097 -0.00258593]
#  [-0.47666619 -0.52297046  0.45125243 -0.57311684 -0.71301636]
#  [ 0.32105262  0.78530031 -0.85918681  0.02111762  0.54147539]]

# %% [markdown]
# ## (d): Implementation
#
# We've provided starter code to load in the dataset and convert it to a list of "windows", consisting of indices into the matrix of word vectors.
#
# We pad each sentence with begin and end tokens `<s>` and `</s>`, which have their own word vector representations; additionally, we convert all words to lowercase, canonicalize digits (e.g. `1.12` becomes `DG.DGDG`), and replace unknown words with a special token `UUUNKKK`.
#
# You don't need to worry about the details of this, but you can inspect the `docs` variables or look at the raw data (in plaintext) in the `./data/` directory.

# %%
import data_utils.utils as du
import data_utils.ner as ner

# %%
# Load the starter word vectors
wv, word_to_num, num_to_word = ner.load_wv('data/ner/vocab.txt',
                                           'data/ner/wordVectors.txt')

print wv[0]
tagnames = ["O", "LOC", "MISC", "ORG", "PER"]
num_to_tag = dict(enumerate(tagnames))
tag_to_num = du.invert_dict(num_to_tag)

# Set window size
windowsize = 3

# Load the training set
docs = du.load_dataset('data/ner/train')
X_train, y_train = du.docs_to_windows(docs, word_to_num, tag_to_num,
                                      wsize=windowsize)

# Load the dev set (for tuning hyperparameters)
docs = du.load_dataset('data/ner/dev')
X_dev, y_dev = du.docs_to_windows(docs, word_to_num, tag_to_num,
                                  wsize=windowsize)

# Load the test set (dummy labels only)
docs = du.load_dataset('data/ner/test.masked')
X_test, y_test = du.docs_to_windows(docs, word_to_num, tag_to_num,
                                    wsize=windowsize)
# Out:
# [ 0.172414 -0.091063  0.255125 -0.837163  0.434872 -0.499848 -0.042904
#  -0.059642 -0.635087 -0.458795 -0.105671  0.506513 -0.105105 -0.405678
#   0.493365  0.408807  0.401635 -0.817805  0.62634   0.580636 -0.246996
#  -0.008515 -0.67114   0.301865 -0.439651  0.247694 -0.291402  0.873009
#   0.216212  0.145576 -0.211101 -0.35236   0.227651 -0.118416  0.371816
#   0.261296  0.017548  0.596692 -0.485722 -0.36953  -0.048807  0.01796
#  -0.040483  0.111193  0.398039  0.162765  0.408946  0.005343 -0.107523
#  -0.079821]

# %% [markdown]
# To avoid re-inventing the wheel, we provide a base class that handles a lot of the drudgery of managing parameters and running gradient descent. It's based on the classifier API used by [`scikit-learn`](http://scikit-learn.org/stable/), so if you're familiar with that library it should be easy to use.
#
# We'll be using this class for the rest of this assignment, so it helps to get acquainted with a simple example that should be familiar from Assignment 1. To keep this notebook uncluttered, we've put the code in the `softmax_example.py`; take a look at it there, then run the cell below.

# %%
from softmax_example import SoftmaxRegression
sr = SoftmaxRegression(wv=zeros((10,100)), dims=(100,5))

##
# Automatic gradient checker!
# this checks anything you add to self.grads or self.sgrads
# using the method of Assignment 1
sr.grad_check(x=5, y=4)
# Out:
# grad_check: dJ/db error norm = 3.565e-10 [ok]
#     b dims: [5] = 5 elem
# grad_check: dJ/dW error norm = 2.206e-11 [ok]
#     W dims: [5, 100] = 500 elem
# grad_check: dJ/dL[5] error norm = 2.453e-11 [ok]
#     L[5] dims: [100] = 100 elem

# %% [markdown]
# In order to implement a model, you need to subclass `NNBase`, then implement the following methods:
#
# - `__init__()` (initialize parameters and hyperparameters)
# - `_acc_grads()` (compute and accumulate gradients)
# - `compute_loss()` (compute loss for a training example)
# - `predict()`, `predict_proba()`, or other prediction method (for evaluation)
#
# `NNBase` provides you with a few others that will be helpful:
#
# - `grad_check()` (run a gradient check - calls `_acc_grads` and `compute_loss`)
# - `train_sgd()` (run SGD training; more on this later)
#
# Your task is to implement the window model in `nerwindow.py`; a scaffold has been provided for you with instructions on what to fill in.
#
# When ready, you can test below:

# %%
from nerwindow import WindowMLP
clf = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
                reg=0.001, alpha=0.01)

#print '*** output ***'
#print y_train[0]
#clf.predict_proba(X_train[0])
#clf.compute_loss(X_train[0], y_train[0])

#clf._acc_grads(X_train[0], y_train[0])
clf.grad_check(X_train[0], y_train[0]) # gradient check on single point
#clf.grad_check_naive(X_train[0], y_train[0], 'W2') # gradient check on single point
# Out:
# grad_check: dJ/db2 error norm = 3.294e-09 [ok]
#     b2 dims: [100] = 100 elem
# grad_check: dJ/dW2 error norm = 3.524e-10 [ok]
#     W2 dims: [5, 100] = 500 elem
# grad_check: dJ/dW1 error norm = 1.545e-08 [ok]
#     W1 dims: [100, 150] = 15000 elem
# grad_check: dJ/db3 error norm = 3.238e-10 [ok]
#     b3 dims: [5] = 5 elem
# grad_check: dJ/dL[30] error norm = 5.029e-11 [ok]
#     L[30] dims: [50] = 50 elem
# grad_check: dJ/dL[6659] error norm = 3.926e-11 [ok]
#     L[6659] dims: [50] = 50 elem
# grad_check: dJ/dL[12637] error norm = 4.241e-11 [ok]
#     L[12637] dims: [50] = 50 elem

# %% [markdown]
# Now we'll train your model on some data! You can implement your own SGD method, but we recommend that you just call `clf.train_sgd`. This takes the following arguments:
#
# - `X`, `y` : training data
# - `idxiter`: iterable (list or generator) that gives index (row of X) of training examples in the order they should be visited by SGD
# - `printevery`: int, prints progress after this many examples
# - `costevery`: int, computes mean loss after this many examples. This is a costly operation, so don't make this too frequent!
#
# The implementation we give you supports minibatch learning; if `idxiter` is a list-of-lists (or yields lists), then gradients will be computed for all indices in a minibatch before modifying the parameters (this is why we have you write `_acc_grad` instead of applying them directly!).
#
# Before training, you should generate a training schedule to pass as `idxiter`. If you know how to use Python generators, we recommend those; otherwise, just make a static list. Make the following in the cell below:
#
# - An "epoch" schedule that just iterates through the training set, in order, `nepoch` times.
# - A random schedule of `N` examples sampled with replacement from the training set.
# - A random schedule of `N/k` minibatches of size `k`, sampled with replacement from the training set.

# %%
nepoch = 5
N = nepoch * len(y_train)
k = 5 # minibatch size

random.seed(10) # do not change this!
#### YOUR CODE HERE ####

def epoch_sched(m=-1): 
    i = 0
    
    if(m < 0):
        m = N
        
    while i < m:
        yield i % l
        i += 1

indices = xrange(0, len(y_train))

def rand_sched(m=-1): 
    if(m < 0):
        m = N
    cnt = 0
    L = len(y_train)
    while cnt < m:
        yield random.randint(0, L)
        cnt += 1

def mb_rand_sched(m=-1): 
    if(m < 0):
        m = N
    cnt = 0
    while cnt < m:
        yield random.choice(indices, k)
        cnt += k

epoch_iter = epoch_sched(100000)
rand_iter = rand_sched(100000)
mb_rand_iter = mb_rand_sched(100000)
#### END YOUR CODE ###

# %% [markdown]
# Now call `train_sgd` to train on `X_train`, `y_train`. To verify that things work, train on 100,000 examples or so to start (with any of the above schedules). This shouldn't take more than a couple minutes, and you should get a mean cross-entropy loss around 0.4.
#
# Now, if this works well, it's time for production! You have three tasks here:
#
# 1. Train a good model
# 2. Plot a learning curve (cost vs. # of iterations)
# 3. Use your best model to predict the test set
#
# You should train on the `train` data and evaluate performance on the `dev` set. The `test` data we provided has only dummy labels (everything is `O`); we'll compare your predictions to the true labels at grading time.
#
# Scroll down to section (f) for the evaluation code.
#
# We don't expect you to spend too much time doing an exhaustive search here; the default parameters should work well, although you can certainly do better. Try to achieve an F1 score of at least 76% on the dev set, as reported by `eval_performance`.
#
# Feel free to create new cells and write new code here, including new functions (helpers and otherwise) in `nerwindow.py`. When you have a good model, follow the instructions below to make predictions on the test set.
#
# A strong model may require 10-20 passes (or equivalent number of random samples) through the training set and could take 20 minutes or more to train - but it's also possible to be much, much faster!
#
# Things you may want to tune:
# - `alpha` (including using an "annealing" schedule to decrease the learning rate over time)
# - training schedule and minibatch size
# - regularization strength
# - hidden layer dimension
# - width of context window

# %%
docs_train = du.load_dataset('data/ner/train')
docs_dev = du.load_dataset('data/ner/dev')

# %%
#### YOUR CODE HERE ####
# Sandbox: build a good model by tuning hyperparameters
random.seed(10) # do not change this!

#idxiter = rand_sched()
#idxiter = mb_rand_sched(50000)
#clf = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
#                reg=0.001, alpha=0.01)
#
#traincurve1 = clf.train_sgd(X_train, y_train, idxiter, printevery=10000/k, costevery=200)
#clf = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
#                reg=0.001, alpha=0.1)
#
#traincurve2 = clf.train_sgd(X_train, y_train, idxiter, printevery=10000/k, costevery=200)

#### END YOUR CODE ####

clfs = []
traincurves = []
f1s = []

for w in [3,5,7]:
    X_train_w, y_train_w = du.docs_to_windows(docs_train, word_to_num, tag_to_num, wsize=w)
    print 'training set loaded...'
    for h in [100, 150, 200]:
        for r in [0, .0001, .001]:
            random.seed(10) # do not change this!
            idxiter = mb_rand_sched()
            print 'running w:%d h:%d: r:%f...' % (w, h, r)
            clf = WindowMLP(wv, windowsize=w, dims=[None, h, 5], reg=r, alpha=0.01)
            traincurves.append( clf.train_sgd(X_train_w, y_train_w, idxiter, printevery=10000000, costevery=10000/k) )
            clfs.append(clf)
# Out:
# training set loaded...
# running w:3 h:100: r:0.000000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.15814
#   [2000]: mean loss 0.370372
#   [4000]: mean loss 0.355699
#   [6000]: mean loss 0.330589
#   [8000]: mean loss 0.319518
#   [10000]: mean loss 0.30548
#   [12000]: mean loss 0.29082
#   [14000]: mean loss 0.292166
#   [16000]: mean loss 0.285188
#   [18000]: mean loss 0.272733
#   [20000]: mean loss 0.270377
#   [22000]: mean loss 0.270969
#   [24000]: mean loss 0.248828
#   [26000]: mean loss 0.247724
#   [28000]: mean loss 0.250953
#   [30000]: mean loss 0.230649
#   [32000]: mean loss 0.232326
#   [34000]: mean loss 0.23022
#   [36000]: mean loss 0.221804
#   [38000]: mean loss 0.215455
#   [40000]: mean loss 0.21262
#   [42000]: mean loss 0.203945
#   [44000]: mean loss 0.195629
#   [46000]: mean loss 0.193137
#   [48000]: mean loss 0.186939
#   [50000]: mean loss 0.186044
#   [52000]: mean loss 0.178049
#   [54000]: mean loss 0.189283
#   [56000]: mean loss 0.179422
#   [58000]: mean loss 0.169213
#   [60000]: mean loss 0.164651
#   [62000]: mean loss 0.167133
#   [64000]: mean loss 0.161901
#   [66000]: mean loss 0.157629
#   [68000]: mean loss 0.165235
#   [70000]: mean loss 0.151366
#   [72000]: mean loss 0.143952
#   [74000]: mean loss 0.15106
#   [76000]: mean loss 0.149526
#   [78000]: mean loss 0.141023
#   [80000]: mean loss 0.136824
#   [82000]: mean loss 0.136532
#   [84000]: mean loss 0.138614
#   [86000]: mean loss 0.131802
#   [88000]: mean loss 0.130673
#   [90000]: mean loss 0.129272
#   [92000]: mean loss 0.126622
#   [94000]: mean loss 0.124758
#   [96000]: mean loss 0.129106
#   [98000]: mean loss 0.124973
#   [100000]: mean loss 0.11831
#   [102000]: mean loss 0.119716
#   [104000]: mean loss 0.116537
#   [106000]: mean loss 0.114678
#   [108000]: mean loss 0.115839
#   [110000]: mean loss 0.111153
#   [112000]: mean loss 0.111581
#   [114000]: mean loss 0.116009
#   [116000]: mean loss 0.11036
#   [118000]: mean loss 0.1114
#   [120000]: mean loss 0.110192
#   [122000]: mean loss 0.102927
#   [124000]: mean loss 0.109231
#   [126000]: mean loss 0.107384
#   [128000]: mean loss 0.105499
#   [130000]: mean loss 0.103825
#   [132000]: mean loss 0.103128
#   [134000]: mean loss 0.110233
#   [136000]: mean loss 0.103641
#   [138000]: mean loss 0.102708
#   [140000]: mean loss 0.100837
#   [142000]: mean loss 0.097286
#   [144000]: mean loss 0.0965435
#   [146000]: mean loss 0.0969119
#   [148000]: mean loss 0.0963944
#   [150000]: mean loss 0.0943714
#   [152000]: mean loss 0.0934834
#   [154000]: mean loss 0.0985656
#   [156000]: mean loss 0.0925724
#   [158000]: mean loss 0.0906544
#   [160000]: mean loss 0.0924408
#   [162000]: mean loss 0.093333
#   [164000]: mean loss 0.0904231
#   [166000]: mean loss 0.0893189
#   [168000]: mean loss 0.0895446
#   [170000]: mean loss 0.0864664
#   [172000]: mean loss 0.0851864
#   [174000]: mean loss 0.0926391
#   [176000]: mean loss 0.0849008
#   [178000]: mean loss 0.0835235
#   [180000]: mean loss 0.0852796
#   [182000]: mean loss 0.0909388
#   [184000]: mean loss 0.0851004
#   [186000]: mean loss 0.0830728
#   [188000]: mean loss 0.0817125
#   [190000]: mean loss 0.080253
#   [192000]: mean loss 0.0791988
#   [194000]: mean loss 0.0798084
#   [196000]: mean loss 0.0778306
#   [198000]: mean loss 0.0780861
#   [200000]: mean loss 0.0791344
#   [202000]: mean loss 0.0785826
#   [203621]: mean loss 0.081836
# SGD complete: 203621 examples in 19185.45 seconds.
# running w:3 h:100: r:0.000100...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.15814
#   [2000]: mean loss 0.370431
#   [4000]: mean loss 0.355755
#   [6000]: mean loss 0.330906
#   [8000]: mean loss 0.320217
#   [10000]: mean loss 0.306284
#   [12000]: mean loss 0.291826
#   [14000]: mean loss 0.29298
#   [16000]: mean loss 0.286305
#   [18000]: mean loss 0.274041
#   [20000]: mean loss 0.271732
#   [22000]: mean loss 0.272692
#   [24000]: mean loss 0.251033
#   [26000]: mean loss 0.250416
#   [28000]: mean loss 0.253045
#   [30000]: mean loss 0.233103
#   [32000]: mean loss 0.235427
#   [34000]: mean loss 0.233241
#   [36000]: mean loss 0.225591
#   [38000]: mean loss 0.21858
#   [40000]: mean loss 0.215677
#   [42000]: mean loss 0.207098
#   [44000]: mean loss 0.198993
#   [46000]: mean loss 0.198279
#   [48000]: mean loss 0.190724
#   [50000]: mean loss 0.190199
#   [52000]: mean loss 0.182212
#   [54000]: mean loss 0.192342
#   [56000]: mean loss 0.184206
#   [58000]: mean loss 0.173765
#   [60000]: mean loss 0.169326
#   [62000]: mean loss 0.172519
#   [64000]: mean loss 0.166021
#   [66000]: mean loss 0.162742
#   [68000]: mean loss 0.169576
#   [70000]: mean loss 0.156053
#   [72000]: mean loss 0.149191
#   [74000]: mean loss 0.156594
#   [76000]: mean loss 0.155731
#   [78000]: mean loss 0.146398
#   [80000]: mean loss 0.142768
#   [82000]: mean loss 0.141635
#   [84000]: mean loss 0.144919
#   [86000]: mean loss 0.137866
#   [88000]: mean loss 0.135831
#   [90000]: mean loss 0.134309
#   [92000]: mean loss 0.132794
#   [94000]: mean loss 0.130621
#   [96000]: mean loss 0.135332
#   [98000]: mean loss 0.1304
#   [100000]: mean loss 0.123647
#   [102000]: mean loss 0.125813
#   [104000]: mean loss 0.122074
#   [106000]: mean loss 0.120671
#   [108000]: mean loss 0.12188
#   [110000]: mean loss 0.116768
#   [112000]: mean loss 0.116738
#   [114000]: mean loss 0.121988
#   [116000]: mean loss 0.116319
#   [118000]: mean loss 0.118591
#   [120000]: mean loss 0.116489
#   [122000]: mean loss 0.109487
#   [124000]: mean loss 0.116683
#   [126000]: mean loss 0.113452
#   [128000]: mean loss 0.111951
#   [130000]: mean loss 0.111123
#   [132000]: mean loss 0.111668
#   [134000]: mean loss 0.117023
#   [136000]: mean loss 0.111847
#   [138000]: mean loss 0.110901
#   [140000]: mean loss 0.107578
#   [142000]: mean loss 0.105828
#   [144000]: mean loss 0.10395
#   [146000]: mean loss 0.102719
#   [148000]: mean loss 0.102859
#   [150000]: mean loss 0.103225
#   [152000]: mean loss 0.100237
#   [154000]: mean loss 0.110709
#   [156000]: mean loss 0.0990385
#   [158000]: mean loss 0.0978405
#   [160000]: mean loss 0.100239
#   [162000]: mean loss 0.101133
#   [164000]: mean loss 0.0994389
#   [166000]: mean loss 0.0980227
#   [168000]: mean loss 0.0970036
#   [170000]: mean loss 0.0940475
#   [172000]: mean loss 0.0924545
#   [174000]: mean loss 0.101417
#   [176000]: mean loss 0.0903793
#   [178000]: mean loss 0.0915112
#   [180000]: mean loss 0.0916276
#   [182000]: mean loss 0.105257
#   [184000]: mean loss 0.0935982
#   [186000]: mean loss 0.0908357
#   [188000]: mean loss 0.0898399
#   [190000]: mean loss 0.0893383
#   [192000]: mean loss 0.0875592
#   [194000]: mean loss 0.0896707
#   [196000]: mean loss 0.0874775
#   [198000]: mean loss 0.0868695
#   [200000]: mean loss 0.0885768
#   [202000]: mean loss 0.0872569
#   [203621]: mean loss 0.0906072
# SGD complete: 203621 examples in 5509.26 seconds.
# running w:3 h:100: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.15814
#   [2000]: mean loss 0.371176
#   [4000]: mean loss 0.356678
#   [6000]: mean loss 0.3341
#   [8000]: mean loss 0.326956
#   [10000]: mean loss 0.313784
#   [12000]: mean loss 0.301215
#   [14000]: mean loss 0.301098
#   [16000]: mean loss 0.296466
#   [18000]: mean loss 0.286121
#   [20000]: mean loss 0.284261
#   [22000]: mean loss 0.287317
#   [24000]: mean loss 0.268502
#   [26000]: mean loss 0.272266
#   [28000]: mean loss 0.271004
#   [30000]: mean loss 0.253943
#   [32000]: mean loss 0.259386
#   [34000]: mean loss 0.260541
#   [36000]: mean loss 0.255126
#   [38000]: mean loss 0.24465
#   [40000]: mean loss 0.241422
#   [42000]: mean loss 0.235711
#   [44000]: mean loss 0.22697
#   [46000]: mean loss 0.231931
#   [48000]: mean loss 0.224018
#   [50000]: mean loss 0.224187
#   [52000]: mean loss 0.216634
#   [54000]: mean loss 0.225905
#   [56000]: mean loss 0.219373
#   [58000]: mean loss 0.207778
#   [60000]: mean loss 0.204417
#   [62000]: mean loss 0.208163
#   [64000]: mean loss 0.200824
#   [66000]: mean loss 0.202359
#   [68000]: mean loss 0.212234
#   [70000]: mean loss 0.194129
#   [72000]: mean loss 0.189107
#   [74000]: mean loss 0.191986
#   [76000]: mean loss 0.19358
#   [78000]: mean loss 0.185237
#   [80000]: mean loss 0.182727
#   [82000]: mean loss 0.180086
#   [84000]: mean loss 0.189654
#   [86000]: mean loss 0.178039
#   [88000]: mean loss 0.179138
#   [90000]: mean loss 0.175846
#   [92000]: mean loss 0.173961
#   [94000]: mean loss 0.175589
#   [96000]: mean loss 0.180787
#   [98000]: mean loss 0.172079
#   [100000]: mean loss 0.165301
#   [102000]: mean loss 0.167598
#   [104000]: mean loss 0.161715
#   [106000]: mean loss 0.162369
#   [108000]: mean loss 0.162791
#   [110000]: mean loss 0.158248
#   [112000]: mean loss 0.160791
#   [114000]: mean loss 0.160489
#   [116000]: mean loss 0.155692
#   [118000]: mean loss 0.161486
#   [120000]: mean loss 0.154326
#   [122000]: mean loss 0.151984
#   [124000]: mean loss 0.160259
#   [126000]: mean loss 0.154758
#   [128000]: mean loss 0.151625
#   [130000]: mean loss 0.153268
#   [132000]: mean loss 0.152519
#   [134000]: mean loss 0.158675
#   [136000]: mean loss 0.153346
#   [138000]: mean loss 0.148002
#   [140000]: mean loss 0.149364
#   [142000]: mean loss 0.15162
#   [144000]: mean loss 0.147575
#   [146000]: mean loss 0.140816
#   [148000]: mean loss 0.140918
#   [150000]: mean loss 0.143948
#   [152000]: mean loss 0.138656
#   [154000]: mean loss 0.143407
#   [156000]: mean loss 0.138737
#   [158000]: mean loss 0.140754
#   [160000]: mean loss 0.136735
#   [162000]: mean loss 0.138302
#   [164000]: mean loss 0.144451
#   [166000]: mean loss 0.139236
#   [168000]: mean loss 0.135315
#   [170000]: mean loss 0.136088
#   [172000]: mean loss 0.131758
#   [174000]: mean loss 0.140714
#   [176000]: mean loss 0.13446
#   [178000]: mean loss 0.134109
#   [180000]: mean loss 0.13337
#   [182000]: mean loss 0.140657
#   [184000]: mean loss 0.130836
#   [186000]: mean loss 0.130366
#   [188000]: mean loss 0.127429
#   [190000]: mean loss 0.127161
#   [192000]: mean loss 0.126511
#   [194000]: mean loss 0.127182
#   [196000]: mean loss 0.129808
#   [198000]: mean loss 0.125457
#   [200000]: mean loss 0.128425
#   [202000]: mean loss 0.127652
#   [203621]: mean loss 0.125412
# SGD complete: 203621 examples in 5147.29 seconds.
# running w:3 h:150: r:0.000000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.80488
#   [2000]: mean loss 0.385202
#   [4000]: mean loss 0.357501
#   [6000]: mean loss 0.338744
#   [8000]: mean loss 0.327302
#   [10000]: mean loss 0.318847
#   [12000]: mean loss 0.319831
#   [14000]: mean loss 0.292976
#   [16000]: mean loss 0.285968
#   [18000]: mean loss 0.278357
#   [20000]: mean loss 0.270568
#   [22000]: mean loss 0.267288
#   [24000]: mean loss 0.259305
#   [26000]: mean loss 0.257985
#   [28000]: mean loss 0.241262
#   [30000]: mean loss 0.235274
#   [32000]: mean loss 0.235625
#   [34000]: mean loss 0.226895
#   [36000]: mean loss 0.221953
#   [38000]: mean loss 0.226428
#   [40000]: mean loss 0.216737
#   [42000]: mean loss 0.209331
#   [44000]: mean loss 0.201933
#   [46000]: mean loss 0.216361
#   [48000]: mean loss 0.191061
#   [50000]: mean loss 0.191743
#   [52000]: mean loss 0.188751
#   [54000]: mean loss 0.184046
#   [56000]: mean loss 0.175289
#   [58000]: mean loss 0.172254
#   [60000]: mean loss 0.167352
#   [62000]: mean loss 0.169102
#   [64000]: mean loss 0.173203
#   [66000]: mean loss 0.161373
#   [68000]: mean loss 0.154166
#   [70000]: mean loss 0.151163
#   [72000]: mean loss 0.157507
#   [74000]: mean loss 0.150204
#   [76000]: mean loss 0.14924
#   [78000]: mean loss 0.145765
#   [80000]: mean loss 0.138628
#   [82000]: mean loss 0.144944
#   [84000]: mean loss 0.138027
#   [86000]: mean loss 0.13718
#   [88000]: mean loss 0.136571
#   [90000]: mean loss 0.133787
#   [92000]: mean loss 0.131077
#   [94000]: mean loss 0.13794
#   [96000]: mean loss 0.134464
#   [98000]: mean loss 0.126067
#   [100000]: mean loss 0.123867
#   [102000]: mean loss 0.121759
#   [104000]: mean loss 0.127439
#   [106000]: mean loss 0.119957
#   [108000]: mean loss 0.123755
#   [110000]: mean loss 0.115828
#   [112000]: mean loss 0.113056
#   [114000]: mean loss 0.113376
#   [116000]: mean loss 0.115901
#   [118000]: mean loss 0.122478
#   [120000]: mean loss 0.10915
#   [122000]: mean loss 0.113784
#   [124000]: mean loss 0.109634
#   [126000]: mean loss 0.104812
#   [128000]: mean loss 0.10516
#   [130000]: mean loss 0.110927
#   [132000]: mean loss 0.104313
#   [134000]: mean loss 0.105657
#   [136000]: mean loss 0.10189
#   [138000]: mean loss 0.100108
#   [140000]: mean loss 0.0999917
#   [142000]: mean loss 0.101209
#   [144000]: mean loss 0.0985401
#   [146000]: mean loss 0.102742
#   [148000]: mean loss 0.0963546
#   [150000]: mean loss 0.102233
#   [152000]: mean loss 0.0932856
#   [154000]: mean loss 0.0950672
#   [156000]: mean loss 0.100999
#   [158000]: mean loss 0.0946552
#   [160000]: mean loss 0.09762
#   [162000]: mean loss 0.0973491
#   [164000]: mean loss 0.0976964
#   [166000]: mean loss 0.0942769
#   [168000]: mean loss 0.0918096
#   [170000]: mean loss 0.0898222
#   [172000]: mean loss 0.0898127
#   [174000]: mean loss 0.0883818
#   [176000]: mean loss 0.0884403
#   [178000]: mean loss 0.0869408
#   [180000]: mean loss 0.0868474
#   [182000]: mean loss 0.0862975
#   [184000]: mean loss 0.0827702
#   [186000]: mean loss 0.0835725
#   [188000]: mean loss 0.0826335
#   [190000]: mean loss 0.0870174
#   [192000]: mean loss 0.082376
#   [194000]: mean loss 0.0879281
#   [196000]: mean loss 0.079686
#   [198000]: mean loss 0.0772053
#   [200000]: mean loss 0.0778005
#   [202000]: mean loss 0.0803989
#   [203621]: mean loss 0.0786215
# SGD complete: 203621 examples in 5035.98 seconds.
# running w:3 h:150: r:0.000100...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.80488
#   [2000]: mean loss 0.385184
#   [4000]: mean loss 0.357645
#   [6000]: mean loss 0.338893
#   [8000]: mean loss 0.327731
#   [10000]: mean loss 0.319178
#   [12000]: mean loss 0.320541
#   [14000]: mean loss 0.294174
#   [16000]: mean loss 0.287236
#   [18000]: mean loss 0.279754
#   [20000]: mean loss 0.271726
#   [22000]: mean loss 0.269018
#   [24000]: mean loss 0.261111
#   [26000]: mean loss 0.260132
#   [28000]: mean loss 0.243684
#   [30000]: mean loss 0.237763
#   [32000]: mean loss 0.238088
#   [34000]: mean loss 0.229473
#   [36000]: mean loss 0.225339
#   [38000]: mean loss 0.229173
#   [40000]: mean loss 0.21956
#   [42000]: mean loss 0.211907
#   [44000]: mean loss 0.205413
#   [46000]: mean loss 0.219415
#   [48000]: mean loss 0.195078
#   [50000]: mean loss 0.19606
#   [52000]: mean loss 0.192405
#   [54000]: mean loss 0.186254
#   [56000]: mean loss 0.180159
#   [58000]: mean loss 0.176727
#   [60000]: mean loss 0.17152
#   [62000]: mean loss 0.173029
#   [64000]: mean loss 0.17829
#   [66000]: mean loss 0.166454
#   [68000]: mean loss 0.158697
#   [70000]: mean loss 0.155721
#   [72000]: mean loss 0.162272
#   [74000]: mean loss 0.154724
#   [76000]: mean loss 0.153239
#   [78000]: mean loss 0.150134
#   [80000]: mean loss 0.143933
#   [82000]: mean loss 0.149318
#   [84000]: mean loss 0.142616
#   [86000]: mean loss 0.143195
#   [88000]: mean loss 0.141012
#   [90000]: mean loss 0.13872
#   [92000]: mean loss 0.13573
#   [94000]: mean loss 0.144158
#   [96000]: mean loss 0.138885
#   [98000]: mean loss 0.131318
#   [100000]: mean loss 0.128151
#   [102000]: mean loss 0.127634
#   [104000]: mean loss 0.132098
#   [106000]: mean loss 0.124728
#   [108000]: mean loss 0.128854
#   [110000]: mean loss 0.121427
#   [112000]: mean loss 0.118809
#   [114000]: mean loss 0.119625
#   [116000]: mean loss 0.121931
#   [118000]: mean loss 0.128943
#   [120000]: mean loss 0.114906
#   [122000]: mean loss 0.118015
#   [124000]: mean loss 0.113968
#   [126000]: mean loss 0.111354
#   [128000]: mean loss 0.111199
#   [130000]: mean loss 0.116831
#   [132000]: mean loss 0.110876
#   [134000]: mean loss 0.110969
#   [136000]: mean loss 0.107906
#   [138000]: mean loss 0.108404
#   [140000]: mean loss 0.107409
#   [142000]: mean loss 0.107609
#   [144000]: mean loss 0.107562
#   [146000]: mean loss 0.108018
#   [148000]: mean loss 0.102729
#   [150000]: mean loss 0.1083
#   [152000]: mean loss 0.100936
#   [154000]: mean loss 0.101915
#   [156000]: mean loss 0.109226
#   [158000]: mean loss 0.103206
#   [160000]: mean loss 0.10405
#   [162000]: mean loss 0.102471
#   [164000]: mean loss 0.103906
#   [166000]: mean loss 0.10001
#   [168000]: mean loss 0.0986884
#   [170000]: mean loss 0.100102
#   [172000]: mean loss 0.0984693
#   [174000]: mean loss 0.0933233
#   [176000]: mean loss 0.0968772
#   [178000]: mean loss 0.093209
#   [180000]: mean loss 0.095237
#   [182000]: mean loss 0.0931608
#   [184000]: mean loss 0.0892448
#   [186000]: mean loss 0.0914267
#   [188000]: mean loss 0.0906667
#   [190000]: mean loss 0.0940227
#   [192000]: mean loss 0.0892721
#   [194000]: mean loss 0.0941398
#   [196000]: mean loss 0.0878832
#   [198000]: mean loss 0.0850418
#   [200000]: mean loss 0.0859352
#   [202000]: mean loss 0.0861172
#   [203621]: mean loss 0.0862515
# SGD complete: 203621 examples in 5031.60 seconds.
# running w:3 h:150: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.80488
#   [2000]: mean loss 0.385234
#   [4000]: mean loss 0.359324
#   [6000]: mean loss 0.340851
#   [8000]: mean loss 0.332213
#   [10000]: mean loss 0.323402
#   [12000]: mean loss 0.328056
#   [14000]: mean loss 0.303594
#   [16000]: mean loss 0.299311
#   [18000]: mean loss 0.291662
#   [20000]: mean loss 0.283481
#   [22000]: mean loss 0.283186
#   [24000]: mean loss 0.277935
#   [26000]: mean loss 0.276643
#   [28000]: mean loss 0.262311
#   [30000]: mean loss 0.25785
#   [32000]: mean loss 0.25746
#   [34000]: mean loss 0.250936
#   [36000]: mean loss 0.249177
#   [38000]: mean loss 0.248912
#   [40000]: mean loss 0.241669
#   [42000]: mean loss 0.252095
#   [44000]: mean loss 0.231475
#   [46000]: mean loss 0.24767
#   [48000]: mean loss 0.224732
#   [50000]: mean loss 0.222151
#   [52000]: mean loss 0.222325
#   [54000]: mean loss 0.215089
#   [56000]: mean loss 0.212303
#   [58000]: mean loss 0.205581
#   [60000]: mean loss 0.203078
#   [62000]: mean loss 0.20156
#   [64000]: mean loss 0.215357
#   [66000]: mean loss 0.19886
#   [68000]: mean loss 0.195225
#   [70000]: mean loss 0.192586
#   [72000]: mean loss 0.198497
#   [74000]: mean loss 0.188195
#   [76000]: mean loss 0.187714
#   [78000]: mean loss 0.186923
#   [80000]: mean loss 0.181899
#   [82000]: mean loss 0.182488
#   [84000]: mean loss 0.185789
#   [86000]: mean loss 0.17891
#   [88000]: mean loss 0.178887
#   [90000]: mean loss 0.180311
#   [92000]: mean loss 0.172011
#   [94000]: mean loss 0.183178
#   [96000]: mean loss 0.174591
#   [98000]: mean loss 0.170959
#   [100000]: mean loss 0.167747
#   [102000]: mean loss 0.167791
#   [104000]: mean loss 0.167791
#   [106000]: mean loss 0.165339
#   [108000]: mean loss 0.169387
#   [110000]: mean loss 0.162014
#   [112000]: mean loss 0.164
#   [114000]: mean loss 0.157193
#   [116000]: mean loss 0.162592
#   [118000]: mean loss 0.165207
#   [120000]: mean loss 0.153434
#   [122000]: mean loss 0.156227
#   [124000]: mean loss 0.153616
#   [126000]: mean loss 0.153432
#   [128000]: mean loss 0.150673
#   [130000]: mean loss 0.155507
#   [132000]: mean loss 0.15
#   [134000]: mean loss 0.146226
#   [136000]: mean loss 0.149898
#   [138000]: mean loss 0.146355
#   [140000]: mean loss 0.150256
#   [142000]: mean loss 0.149606
#   [144000]: mean loss 0.146946
#   [146000]: mean loss 0.152896
#   [148000]: mean loss 0.142552
#   [150000]: mean loss 0.148948
#   [152000]: mean loss 0.13757
#   [154000]: mean loss 0.140227
#   [156000]: mean loss 0.149769
#   [158000]: mean loss 0.143904
#   [160000]: mean loss 0.141633
#   [162000]: mean loss 0.140567
#   [164000]: mean loss 0.141891
#   [166000]: mean loss 0.139747
#   [168000]: mean loss 0.133876
#   [170000]: mean loss 0.138812
#   [172000]: mean loss 0.136108
#   [174000]: mean loss 0.13141
#   [176000]: mean loss 0.134955
#   [178000]: mean loss 0.13418
#   [180000]: mean loss 0.132337
#   [182000]: mean loss 0.1327
#   [184000]: mean loss 0.129259
#   [186000]: mean loss 0.129451
#   [188000]: mean loss 0.129467
#   [190000]: mean loss 0.130594
#   [192000]: mean loss 0.129161
#   [194000]: mean loss 0.134298
#   [196000]: mean loss 0.127507
#   [198000]: mean loss 0.128642
#   [200000]: mean loss 0.124402
#   [202000]: mean loss 0.123817
#   [203621]: mean loss 0.125121
# SGD complete: 203621 examples in 5060.59 seconds.
# running w:3 h:200: r:0.000000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.45971
#   [2000]: mean loss 0.38868
#   [4000]: mean loss 0.348961
#   [6000]: mean loss 0.339771
#   [8000]: mean loss 0.329946
#   [10000]: mean loss 0.310913
#   [12000]: mean loss 0.310204
#   [14000]: mean loss 0.293957
#   [16000]: mean loss 0.289737
#   [18000]: mean loss 0.277518
#   [20000]: mean loss 0.281996
#   [22000]: mean loss 0.26932
#   [24000]: mean loss 0.2647
#   [26000]: mean loss 0.252158
#   [28000]: mean loss 0.255968
#   [30000]: mean loss 0.24602
#   [32000]: mean loss 0.240323
#   [34000]: mean loss 0.267652
#   [36000]: mean loss 0.229775
#   [38000]: mean loss 0.224997
#   [40000]: mean loss 0.222967
#   [42000]: mean loss 0.208833
#   [44000]: mean loss 0.210106
#   [46000]: mean loss 0.198541
#   [48000]: mean loss 0.192885
#   [50000]: mean loss 0.18942
#   [52000]: mean loss 0.194454
#   [54000]: mean loss 0.184098
#   [56000]: mean loss 0.179551
#   [58000]: mean loss 0.177571
#   [60000]: mean loss 0.174899
#   [62000]: mean loss 0.172341
#   [64000]: mean loss 0.164654
#   [66000]: mean loss 0.1709
#   [68000]: mean loss 0.157958
#   [70000]: mean loss 0.165465
#   [72000]: mean loss 0.155986
#   [74000]: mean loss 0.15753
#   [76000]: mean loss 0.150003
#   [78000]: mean loss 0.157502
#   [80000]: mean loss 0.14533
#   [82000]: mean loss 0.144598
#   [84000]: mean loss 0.14213
#   [86000]: mean loss 0.141953
#   [88000]: mean loss 0.140265
#   [90000]: mean loss 0.13742
#   [92000]: mean loss 0.132296
#   [94000]: mean loss 0.136401
#   [96000]: mean loss 0.136133
#   [98000]: mean loss 0.129044
#   [100000]: mean loss 0.124672
#   [102000]: mean loss 0.150573
#   [104000]: mean loss 0.130796
#   [106000]: mean loss 0.124294
#   [108000]: mean loss 0.128108
#   [110000]: mean loss 0.122029
#   [112000]: mean loss 0.125476
#   [114000]: mean loss 0.115629
#   [116000]: mean loss 0.114823
#   [118000]: mean loss 0.118473
#   [120000]: mean loss 0.115706
#   [122000]: mean loss 0.110998
#   [124000]: mean loss 0.108065
#   [126000]: mean loss 0.114227
#   [128000]: mean loss 0.10945
#   [130000]: mean loss 0.110103
#   [132000]: mean loss 0.108002
#   [134000]: mean loss 0.105036
#   [136000]: mean loss 0.104886
#   [138000]: mean loss 0.10603
#   [140000]: mean loss 0.101495
#   [142000]: mean loss 0.102242
#   [144000]: mean loss 0.101812
#   [146000]: mean loss 0.101478
#   [148000]: mean loss 0.103381
#   [150000]: mean loss 0.102939
#   [152000]: mean loss 0.101644
#   [154000]: mean loss 0.0965308
#   [156000]: mean loss 0.100793
#   [158000]: mean loss 0.0961058
#   [160000]: mean loss 0.0930285
#   [162000]: mean loss 0.0904622
#   [164000]: mean loss 0.0953574
#   [166000]: mean loss 0.0926633
#   [168000]: mean loss 0.0945525
#   [170000]: mean loss 0.0879433
#   [172000]: mean loss 0.0901957
#   [174000]: mean loss 0.0924899
#   [176000]: mean loss 0.0888984
#   [178000]: mean loss 0.0876972
#   [180000]: mean loss 0.0877524
#   [182000]: mean loss 0.0902194
#   [184000]: mean loss 0.0855743
#   [186000]: mean loss 0.088699
#   [188000]: mean loss 0.087605
#   [190000]: mean loss 0.0877184
#   [192000]: mean loss 0.0885605
#   [194000]: mean loss 0.0855074
#   [196000]: mean loss 0.0857601
#   [198000]: mean loss 0.0826162
#   [200000]: mean loss 0.085025
#   [202000]: mean loss 0.0884308
#   [203621]: mean loss 0.0784821
# SGD complete: 203621 examples in 5136.94 seconds.
# running w:3 h:200: r:0.000100...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.45971
#   [2000]: mean loss 0.388675
#   [4000]: mean loss 0.349097
#   [6000]: mean loss 0.339987
#   [8000]: mean loss 0.330211
#   [10000]: mean loss 0.311481
#   [12000]: mean loss 0.310852
#   [14000]: mean loss 0.294897
#   [16000]: mean loss 0.290938
#   [18000]: mean loss 0.279059
#   [20000]: mean loss 0.282708
#   [22000]: mean loss 0.271286
#   [24000]: mean loss 0.266531
#   [26000]: mean loss 0.254375
#   [28000]: mean loss 0.257647
#   [30000]: mean loss 0.248382
#   [32000]: mean loss 0.242916
#   [34000]: mean loss 0.26876
#   [36000]: mean loss 0.232047
#   [38000]: mean loss 0.228886
#   [40000]: mean loss 0.226856
#   [42000]: mean loss 0.212854
#   [44000]: mean loss 0.213759
#   [46000]: mean loss 0.202774
#   [48000]: mean loss 0.197093
#   [50000]: mean loss 0.193683
#   [52000]: mean loss 0.198482
#   [54000]: mean loss 0.188507
#   [56000]: mean loss 0.184204
#   [58000]: mean loss 0.181433
#   [60000]: mean loss 0.179316
#   [62000]: mean loss 0.176969
#   [64000]: mean loss 0.168963
#   [66000]: mean loss 0.17391
#   [68000]: mean loss 0.162893
#   [70000]: mean loss 0.169327
#   [72000]: mean loss 0.159561
#   [74000]: mean loss 0.161531
#   [76000]: mean loss 0.15468
#   [78000]: mean loss 0.163993
#   [80000]: mean loss 0.150986
#   [82000]: mean loss 0.150161
#   [84000]: mean loss 0.146897
#   [86000]: mean loss 0.147586
#   [88000]: mean loss 0.144281
#   [90000]: mean loss 0.142303
#   [92000]: mean loss 0.137573
#   [94000]: mean loss 0.142136
#   [96000]: mean loss 0.140463
#   [98000]: mean loss 0.133633
#   [100000]: mean loss 0.130391
#   [102000]: mean loss 0.153561
#   [104000]: mean loss 0.137015
#   [106000]: mean loss 0.129835
#   [108000]: mean loss 0.131598
#   [110000]: mean loss 0.127811
#   [112000]: mean loss 0.130778
#   [114000]: mean loss 0.120887
#   [116000]: mean loss 0.120225
#   [118000]: mean loss 0.122317
#   [120000]: mean loss 0.120618
#   [122000]: mean loss 0.11656
#   [124000]: mean loss 0.112739
#   [126000]: mean loss 0.119687
#   [128000]: mean loss 0.11484
#   [130000]: mean loss 0.114441
#   [132000]: mean loss 0.111321
#   [134000]: mean loss 0.111724
#   [136000]: mean loss 0.109444
#   [138000]: mean loss 0.110342
#   [140000]: mean loss 0.10611
#   [142000]: mean loss 0.10712
#   [144000]: mean loss 0.107232
#   [146000]: mean loss 0.106593
#   [148000]: mean loss 0.109324
#   [150000]: mean loss 0.107179
#   [152000]: mean loss 0.106948
#   [154000]: mean loss 0.102293
#   [156000]: mean loss 0.10638
#   [158000]: mean loss 0.102551
#   [160000]: mean loss 0.0989534
#   [162000]: mean loss 0.0967193
#   [164000]: mean loss 0.101103
#   [166000]: mean loss 0.0995337
#   [168000]: mean loss 0.100313
#   [170000]: mean loss 0.0943336
#   [172000]: mean loss 0.0955303
#   [174000]: mean loss 0.0976216
#   [176000]: mean loss 0.094926
#   [178000]: mean loss 0.0945268
#   [180000]: mean loss 0.0941541
#   [182000]: mean loss 0.0946395
#   [184000]: mean loss 0.0931419
#   [186000]: mean loss 0.0932055
#   [188000]: mean loss 0.0928712
#   [190000]: mean loss 0.0933567
#   [192000]: mean loss 0.0974554
#   [194000]: mean loss 0.0922563
#   [196000]: mean loss 0.0905904
#   [198000]: mean loss 0.0892926
#   [200000]: mean loss 0.0917317
#   [202000]: mean loss 0.097957
#   [203621]: mean loss 0.0856171
# SGD complete: 203621 examples in 5138.73 seconds.
# running w:3 h:200: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.45971
#   [2000]: mean loss 0.388826
#   [4000]: mean loss 0.350763
#   [6000]: mean loss 0.342378
#   [8000]: mean loss 0.333229
#   [10000]: mean loss 0.316883
#   [12000]: mean loss 0.317195
#   [14000]: mean loss 0.303292
#   [16000]: mean loss 0.301385
#   [18000]: mean loss 0.292202
#   [20000]: mean loss 0.291769
#   [22000]: mean loss 0.28638
#   [24000]: mean loss 0.281323
#   [26000]: mean loss 0.270949
#   [28000]: mean loss 0.273402
#   [30000]: mean loss 0.267136
#   [32000]: mean loss 0.262246
#   [34000]: mean loss 0.281809
#   [36000]: mean loss 0.251957
#   [38000]: mean loss 0.253339
#   [40000]: mean loss 0.249901
#   [42000]: mean loss 0.239099
#   [44000]: mean loss 0.239299
#   [46000]: mean loss 0.233662
#   [48000]: mean loss 0.227763
#   [50000]: mean loss 0.224721
#   [52000]: mean loss 0.224709
#   [54000]: mean loss 0.224678
#   [56000]: mean loss 0.215174
#   [58000]: mean loss 0.212809
#   [60000]: mean loss 0.211805
#   [62000]: mean loss 0.207855
#   [64000]: mean loss 0.20132
#   [66000]: mean loss 0.20314
#   [68000]: mean loss 0.198856
#   [70000]: mean loss 0.205745
#   [72000]: mean loss 0.189447
#   [74000]: mean loss 0.19178
#   [76000]: mean loss 0.185365
#   [78000]: mean loss 0.196281
#   [80000]: mean loss 0.186175
#   [82000]: mean loss 0.188824
#   [84000]: mean loss 0.182393
#   [86000]: mean loss 0.181765
#   [88000]: mean loss 0.178773
#   [90000]: mean loss 0.17652
#   [92000]: mean loss 0.172988
#   [94000]: mean loss 0.17912
#   [96000]: mean loss 0.176745
#   [98000]: mean loss 0.170147
#   [100000]: mean loss 0.17072
#   [102000]: mean loss 0.185223
#   [104000]: mean loss 0.173778
#   [106000]: mean loss 0.16937
#   [108000]: mean loss 0.167329
#   [110000]: mean loss 0.166724
#   [112000]: mean loss 0.172162
#   [114000]: mean loss 0.160659
#   [116000]: mean loss 0.160775
#   [118000]: mean loss 0.161767
#   [120000]: mean loss 0.159589
#   [122000]: mean loss 0.154534
#   [124000]: mean loss 0.15508
#   [126000]: mean loss 0.153374
#   [128000]: mean loss 0.158155
#   [130000]: mean loss 0.152151
#   [132000]: mean loss 0.147547
#   [134000]: mean loss 0.149332
#   [136000]: mean loss 0.147628
#   [138000]: mean loss 0.149269
#   [140000]: mean loss 0.146002
#   [142000]: mean loss 0.147389
#   [144000]: mean loss 0.145218
#   [146000]: mean loss 0.142587
#   [148000]: mean loss 0.150447
#   [150000]: mean loss 0.140716
#   [152000]: mean loss 0.145362
#   [154000]: mean loss 0.141858
#   [156000]: mean loss 0.143236
#   [158000]: mean loss 0.140451
#   [160000]: mean loss 0.138019
#   [162000]: mean loss 0.134579
#   [164000]: mean loss 0.141324
#   [166000]: mean loss 0.139942
#   [168000]: mean loss 0.136641
#   [170000]: mean loss 0.132608
#   [172000]: mean loss 0.132397
#   [174000]: mean loss 0.138237
#   [176000]: mean loss 0.132961
#   [178000]: mean loss 0.13496
#   [180000]: mean loss 0.134175
#   [182000]: mean loss 0.131951
#   [184000]: mean loss 0.132197
#   [186000]: mean loss 0.135429
#   [188000]: mean loss 0.132045
#   [190000]: mean loss 0.129561
#   [192000]: mean loss 0.132896
#   [194000]: mean loss 0.130405
#   [196000]: mean loss 0.128107
#   [198000]: mean loss 0.127679
#   [200000]: mean loss 0.126488
#   [202000]: mean loss 0.13323
#   [203621]: mean loss 0.126383
# SGD complete: 203621 examples in 5130.38 seconds.
# training set loaded...
# running w:5 h:100: r:0.000000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.93161
#   [2000]: mean loss 0.361424
#   [4000]: mean loss 0.330269
#   [6000]: mean loss 0.315279
#   [8000]: mean loss 0.309352
#   [10000]: mean loss 0.299927
#   [12000]: mean loss 0.27584
#   [14000]: mean loss 0.27851
#   [16000]: mean loss 0.253793
#   [18000]: mean loss 0.264806
#   [20000]: mean loss 0.247679
#   [22000]: mean loss 0.23747
#   [24000]: mean loss 0.247407
#   [26000]: mean loss 0.248088
#   [28000]: mean loss 0.23214
#   [30000]: mean loss 0.218569
#   [32000]: mean loss 0.214268
#   [34000]: mean loss 0.213548
#   [36000]: mean loss 0.203965
#   [38000]: mean loss 0.21454
#   [40000]: mean loss 0.194479
#   [42000]: mean loss 0.194773
#   [44000]: mean loss 0.194973
#   [46000]: mean loss 0.187989
#   [48000]: mean loss 0.184825
#   [50000]: mean loss 0.177117
#   [52000]: mean loss 0.176516
#   [54000]: mean loss 0.17281
#   [56000]: mean loss 0.177948
#   [58000]: mean loss 0.161353
#   [60000]: mean loss 0.163694
#   [62000]: mean loss 0.159124
#   [64000]: mean loss 0.170421
#   [66000]: mean loss 0.149013
#   [68000]: mean loss 0.161265
#   [70000]: mean loss 0.153495
#   [72000]: mean loss 0.147414
#   [74000]: mean loss 0.147738
#   [76000]: mean loss 0.142254
#   [78000]: mean loss 0.142367
#   [80000]: mean loss 0.140606
#   [82000]: mean loss 0.137873
#   [84000]: mean loss 0.135305
#   [86000]: mean loss 0.134042
#   [88000]: mean loss 0.13443
#   [90000]: mean loss 0.127261
#   [92000]: mean loss 0.124488
#   [94000]: mean loss 0.120765
#   [96000]: mean loss 0.132286
#   [98000]: mean loss 0.118465
#   [100000]: mean loss 0.118542
#   [102000]: mean loss 0.131731
#   [104000]: mean loss 0.13133
#   [106000]: mean loss 0.112511
#   [108000]: mean loss 0.110938
#   [110000]: mean loss 0.103564
#   [112000]: mean loss 0.108937
#   [114000]: mean loss 0.103049
#   [116000]: mean loss 0.111233
#   [118000]: mean loss 0.102035
#   [120000]: mean loss 0.103037
#   [122000]: mean loss 0.104209
#   [124000]: mean loss 0.105728
#   [126000]: mean loss 0.0937435
#   [128000]: mean loss 0.0944625
#   [130000]: mean loss 0.0918502
#   [132000]: mean loss 0.0925682
#   [134000]: mean loss 0.090451
#   [136000]: mean loss 0.0885132
#   [138000]: mean loss 0.0888096
#   [140000]: mean loss 0.091691
#   [142000]: mean loss 0.0965641
#   [144000]: mean loss 0.0822355
#   [146000]: mean loss 0.0849438
#   [148000]: mean loss 0.085852
#   [150000]: mean loss 0.0899194
#   [152000]: mean loss 0.0850011
#   [154000]: mean loss 0.0828878
#   [156000]: mean loss 0.0846932
#   [158000]: mean loss 0.0781671
#   [160000]: mean loss 0.0802366
#   [162000]: mean loss 0.0769653
#   [164000]: mean loss 0.0842825
#   [166000]: mean loss 0.074778
#   [168000]: mean loss 0.0751656
#   [170000]: mean loss 0.0732094
#   [172000]: mean loss 0.0805785
#   [174000]: mean loss 0.0713067
#   [176000]: mean loss 0.0727192
#   [178000]: mean loss 0.068689
#   [180000]: mean loss 0.0729068
#   [182000]: mean loss 0.0680842
#   [184000]: mean loss 0.0706501
#   [186000]: mean loss 0.0707346
#   [188000]: mean loss 0.0669863
#   [190000]: mean loss 0.0656547
#   [192000]: mean loss 0.0645477
#   [194000]: mean loss 0.0698444
#   [196000]: mean loss 0.0629454
#   [198000]: mean loss 0.0644941
#   [200000]: mean loss 0.0633355
#   [202000]: mean loss 0.0699922
#   [203621]: mean loss 0.0609576
# SGD complete: 203621 examples in 5420.91 seconds.
# running w:5 h:100: r:0.000100...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.93161
#   [2000]: mean loss 0.361451
#   [4000]: mean loss 0.330648
#   [6000]: mean loss 0.315713
#   [8000]: mean loss 0.310144
#   [10000]: mean loss 0.300628
#   [12000]: mean loss 0.276641
#   [14000]: mean loss 0.279818
#   [16000]: mean loss 0.254966
#   [18000]: mean loss 0.266124
#   [20000]: mean loss 0.249149
#   [22000]: mean loss 0.239045
#   [24000]: mean loss 0.249535
#   [26000]: mean loss 0.249958
#   [28000]: mean loss 0.234395
#   [30000]: mean loss 0.220983
#   [32000]: mean loss 0.216517
#   [34000]: mean loss 0.215687
#   [36000]: mean loss 0.206832
#   [38000]: mean loss 0.217415
#   [40000]: mean loss 0.197534
#   [42000]: mean loss 0.197672
#   [44000]: mean loss 0.197904
#   [46000]: mean loss 0.191618
#   [48000]: mean loss 0.189119
#   [50000]: mean loss 0.18061
#   [52000]: mean loss 0.179953
#   [54000]: mean loss 0.176791
#   [56000]: mean loss 0.182625
#   [58000]: mean loss 0.165782
#   [60000]: mean loss 0.168749
#   [62000]: mean loss 0.165159
#   [64000]: mean loss 0.174813
#   [66000]: mean loss 0.154472
#   [68000]: mean loss 0.164532
#   [70000]: mean loss 0.156956
#   [72000]: mean loss 0.15304
#   [74000]: mean loss 0.153705
#   [76000]: mean loss 0.147398
#   [78000]: mean loss 0.146462
#   [80000]: mean loss 0.145519
#   [82000]: mean loss 0.142869
#   [84000]: mean loss 0.141017
#   [86000]: mean loss 0.140967
#   [88000]: mean loss 0.140805
#   [90000]: mean loss 0.133828
#   [92000]: mean loss 0.129862
#   [94000]: mean loss 0.126514
#   [96000]: mean loss 0.137073
#   [98000]: mean loss 0.124091
#   [100000]: mean loss 0.126581
#   [102000]: mean loss 0.132171
#   [104000]: mean loss 0.137553
#   [106000]: mean loss 0.121099
#   [108000]: mean loss 0.117131
#   [110000]: mean loss 0.109888
#   [112000]: mean loss 0.116035
#   [114000]: mean loss 0.109393
#   [116000]: mean loss 0.120774
#   [118000]: mean loss 0.106939
#   [120000]: mean loss 0.109683
#   [122000]: mean loss 0.108632
#   [124000]: mean loss 0.11289
#   [126000]: mean loss 0.102677
#   [128000]: mean loss 0.101851
#   [130000]: mean loss 0.0994097
#   [132000]: mean loss 0.0985697
#   [134000]: mean loss 0.0989922
#   [136000]: mean loss 0.0977808
#   [138000]: mean loss 0.0956641
#   [140000]: mean loss 0.0984094
#   [142000]: mean loss 0.103614
#   [144000]: mean loss 0.091492
#   [146000]: mean loss 0.0946297
#   [148000]: mean loss 0.0970788
#   [150000]: mean loss 0.0978376
#   [152000]: mean loss 0.0927543
#   [154000]: mean loss 0.0915327
#   [156000]: mean loss 0.0981242
#   [158000]: mean loss 0.0867438
#   [160000]: mean loss 0.087635
#   [162000]: mean loss 0.0857638
#   [164000]: mean loss 0.0935406
#   [166000]: mean loss 0.0833634
#   [168000]: mean loss 0.0865162
#   [170000]: mean loss 0.0787539
#   [172000]: mean loss 0.0887293
#   [174000]: mean loss 0.080782
#   [176000]: mean loss 0.0820855
#   [178000]: mean loss 0.0801785
#   [180000]: mean loss 0.0857354
#   [182000]: mean loss 0.0777948
#   [184000]: mean loss 0.0794792
#   [186000]: mean loss 0.0803022
#   [188000]: mean loss 0.0788409
#   [190000]: mean loss 0.0737513
#   [192000]: mean loss 0.0751968
#   [194000]: mean loss 0.0764107
#   [196000]: mean loss 0.0746293
#   [198000]: mean loss 0.0744236
#   [200000]: mean loss 0.072977
#   [202000]: mean loss 0.0811096
#   [203621]: mean loss 0.0704254
# SGD complete: 203621 examples in 5641.22 seconds.
# running w:5 h:100: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.93161
#   [2000]: mean loss 0.361942
#   [4000]: mean loss 0.334176
#   [6000]: mean loss 0.320432
#   [8000]: mean loss 0.317763
#   [10000]: mean loss 0.307619
#   [12000]: mean loss 0.284439
#   [14000]: mean loss 0.291978
#   [16000]: mean loss 0.267102
#   [18000]: mean loss 0.280179
#   [20000]: mean loss 0.264005
#   [22000]: mean loss 0.255709
#   [24000]: mean loss 0.267318
#   [26000]: mean loss 0.269875
#   [28000]: mean loss 0.25752
#   [30000]: mean loss 0.24384
#   [32000]: mean loss 0.237668
#   [34000]: mean loss 0.24128
#   [36000]: mean loss 0.229324
#   [38000]: mean loss 0.239232
#   [40000]: mean loss 0.223536
#   [42000]: mean loss 0.223538
#   [44000]: mean loss 0.229054
#   [46000]: mean loss 0.217766
#   [48000]: mean loss 0.219264
#   [50000]: mean loss 0.206908
#   [52000]: mean loss 0.210314
#   [54000]: mean loss 0.207732
#   [56000]: mean loss 0.215648
#   [58000]: mean loss 0.197594
#   [60000]: mean loss 0.20676
#   [62000]: mean loss 0.198033
#   [64000]: mean loss 0.203483
#   [66000]: mean loss 0.188718
#   [68000]: mean loss 0.203657
#   [70000]: mean loss 0.188199
#   [72000]: mean loss 0.187173
#   [74000]: mean loss 0.188695
#   [76000]: mean loss 0.185292
#   [78000]: mean loss 0.179545
#   [80000]: mean loss 0.182844
#   [82000]: mean loss 0.179802
#   [84000]: mean loss 0.176274
#   [86000]: mean loss 0.181131
#   [88000]: mean loss 0.17749
#   [90000]: mean loss 0.167191
#   [92000]: mean loss 0.166534
#   [94000]: mean loss 0.163276
#   [96000]: mean loss 0.17369
#   [98000]: mean loss 0.16359
#   [100000]: mean loss 0.165102
#   [102000]: mean loss 0.165962
#   [104000]: mean loss 0.170342
#   [106000]: mean loss 0.161085
#   [108000]: mean loss 0.161351
#   [110000]: mean loss 0.152772
#   [112000]: mean loss 0.162215
#   [114000]: mean loss 0.150833
#   [116000]: mean loss 0.158311
#   [118000]: mean loss 0.15036
#   [120000]: mean loss 0.149721
#   [122000]: mean loss 0.146369
#   [124000]: mean loss 0.15524
#   [126000]: mean loss 0.146653
#   [128000]: mean loss 0.146946
#   [130000]: mean loss 0.141183
#   [132000]: mean loss 0.139653
#   [134000]: mean loss 0.137876
#   [136000]: mean loss 0.141372
#   [138000]: mean loss 0.14399
#   [140000]: mean loss 0.141191
#   [142000]: mean loss 0.140792
#   [144000]: mean loss 0.137145
#   [146000]: mean loss 0.142501
#   [148000]: mean loss 0.146006
#   [150000]: mean loss 0.137498
#   [152000]: mean loss 0.133151
#   [154000]: mean loss 0.140383
#   [156000]: mean loss 0.138731
#   [158000]: mean loss 0.131038
#   [160000]: mean loss 0.135103
#   [162000]: mean loss 0.13
#   [164000]: mean loss 0.131601
#   [166000]: mean loss 0.1261
#   [168000]: mean loss 0.132897
#   [170000]: mean loss 0.12425
#   [172000]: mean loss 0.128711
#   [174000]: mean loss 0.124049
#   [176000]: mean loss 0.130713
#   [178000]: mean loss 0.121571
#   [180000]: mean loss 0.129044
#   [182000]: mean loss 0.122042
#   [184000]: mean loss 0.119314
#   [186000]: mean loss 0.121966
#   [188000]: mean loss 0.124671
#   [190000]: mean loss 0.120054
#   [192000]: mean loss 0.119794
#   [194000]: mean loss 0.116272
#   [196000]: mean loss 0.117722
#   [198000]: mean loss 0.119651
#   [200000]: mean loss 0.115341
#   [202000]: mean loss 0.122883
#   [203621]: mean loss 0.119782
# SGD complete: 203621 examples in 5590.06 seconds.
# running w:5 h:150: r:0.000000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.89529
#   [2000]: mean loss 0.373085
#   [4000]: mean loss 0.357547
#   [6000]: mean loss 0.327563
#   [8000]: mean loss 0.311644
#   [10000]: mean loss 0.295957
#   [12000]: mean loss 0.29227
#   [14000]: mean loss 0.273072
#   [16000]: mean loss 0.266688
#   [18000]: mean loss 0.267557
#   [20000]: mean loss 0.25158
#   [22000]: mean loss 0.25563
#   [24000]: mean loss 0.245068
#   [26000]: mean loss 0.234501
#   [28000]: mean loss 0.226994
#   [30000]: mean loss 0.221051
#   [32000]: mean loss 0.223018
#   [34000]: mean loss 0.224608
#   [36000]: mean loss 0.204864
#   [38000]: mean loss 0.199047
#   [40000]: mean loss 0.221962
#   [42000]: mean loss 0.199446
#   [44000]: mean loss 0.189483
#   [46000]: mean loss 0.187826
#   [48000]: mean loss 0.185576
#   [50000]: mean loss 0.18581
#   [52000]: mean loss 0.18341
#   [54000]: mean loss 0.182248
#   [56000]: mean loss 0.165301
#   [58000]: mean loss 0.17154
#   [60000]: mean loss 0.17182
#   [62000]: mean loss 0.158915
#   [64000]: mean loss 0.164949
#   [66000]: mean loss 0.162263
#   [68000]: mean loss 0.15143
#   [70000]: mean loss 0.157637
#   [72000]: mean loss 0.157333
#   [74000]: mean loss 0.144043
#   [76000]: mean loss 0.146421
#   [78000]: mean loss 0.133739
#   [80000]: mean loss 0.140401
#   [82000]: mean loss 0.133594
#   [84000]: mean loss 0.14834
#   [86000]: mean loss 0.125405
#   [88000]: mean loss 0.131256
#   [90000]: mean loss 0.12759
#   [92000]: mean loss 0.133168
#   [94000]: mean loss 0.122189
#   [96000]: mean loss 0.127607
#   [98000]: mean loss 0.124421
#   [100000]: mean loss 0.125089
#   [102000]: mean loss 0.112613
#   [104000]: mean loss 0.11529
#   [106000]: mean loss 0.113994
#   [108000]: mean loss 0.110951
#   [110000]: mean loss 0.113503
#   [112000]: mean loss 0.110946
#   [114000]: mean loss 0.107102
#   [116000]: mean loss 0.101905
#   [118000]: mean loss 0.100179
#   [120000]: mean loss 0.103637
#   [122000]: mean loss 0.107269
#   [124000]: mean loss 0.105738
#   [126000]: mean loss 0.098128
#   [128000]: mean loss 0.0914869
#   [130000]: mean loss 0.120315
#   [132000]: mean loss 0.0899979
#   [134000]: mean loss 0.0889984
#   [136000]: mean loss 0.0991821
#   [138000]: mean loss 0.111443
#   [140000]: mean loss 0.0894517
#   [142000]: mean loss 0.0857067
#   [144000]: mean loss 0.0884662
#   [146000]: mean loss 0.0867548
#   [148000]: mean loss 0.0829679
#   [150000]: mean loss 0.0862782
#   [152000]: mean loss 0.0900519
#   [154000]: mean loss 0.0768173
#   [156000]: mean loss 0.0826228
#   [158000]: mean loss 0.0781598
#   [160000]: mean loss 0.0794377
#   [162000]: mean loss 0.0762442
#   [164000]: mean loss 0.074627
#   [166000]: mean loss 0.0802064
#   [168000]: mean loss 0.0779769
#   [170000]: mean loss 0.0716636
#   [172000]: mean loss 0.0828262
#   [174000]: mean loss 0.0711815
#   [176000]: mean loss 0.0740979
#   [178000]: mean loss 0.0685421
#   [180000]: mean loss 0.0682023
#   [182000]: mean loss 0.0711348
#   [184000]: mean loss 0.0737179
#   [186000]: mean loss 0.0769856
#   [188000]: mean loss 0.06645
#   [190000]: mean loss 0.0643048
#   [192000]: mean loss 0.0653728
#   [194000]: mean loss 0.0686319
#   [196000]: mean loss 0.0643975
#   [198000]: mean loss 0.0738022
#   [200000]: mean loss 0.0666089
#   [202000]: mean loss 0.0650935
#   [203621]: mean loss 0.0617544
# SGD complete: 203621 examples in 5913.25 seconds.
# running w:5 h:150: r:0.000100...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.89529
#   [2000]: mean loss 0.373064
#   [4000]: mean loss 0.357858
#   [6000]: mean loss 0.327864
#   [8000]: mean loss 0.311991
#   [10000]: mean loss 0.296743
#   [12000]: mean loss 0.2927
#   [14000]: mean loss 0.273821
#   [16000]: mean loss 0.267448
#   [18000]: mean loss 0.267548
#   [20000]: mean loss 0.252981
#   [22000]: mean loss 0.256755
#   [24000]: mean loss 0.247257
#   [26000]: mean loss 0.236521
#   [28000]: mean loss 0.228604
#   [30000]: mean loss 0.2233
#   [32000]: mean loss 0.22452
#   [34000]: mean loss 0.226081
#   [36000]: mean loss 0.207318
#   [38000]: mean loss 0.201458
#   [40000]: mean loss 0.224308
#   [42000]: mean loss 0.203466
#   [44000]: mean loss 0.193075
#   [46000]: mean loss 0.192394
#   [48000]: mean loss 0.18894
#   [50000]: mean loss 0.189477
#   [52000]: mean loss 0.186773
#   [54000]: mean loss 0.186622
#   [56000]: mean loss 0.170034
#   [58000]: mean loss 0.174026
#   [60000]: mean loss 0.17476
#   [62000]: mean loss 0.162762
#   [64000]: mean loss 0.167713
#   [66000]: mean loss 0.164651
#   [68000]: mean loss 0.155638
#   [70000]: mean loss 0.161764
#   [72000]: mean loss 0.161694
#   [74000]: mean loss 0.148119
#   [76000]: mean loss 0.150863
#   [78000]: mean loss 0.139206
#   [80000]: mean loss 0.144668
#   [82000]: mean loss 0.137957
#   [84000]: mean loss 0.150959
#   [86000]: mean loss 0.132606
#   [88000]: mean loss 0.137093
#   [90000]: mean loss 0.133222
#   [92000]: mean loss 0.137507
#   [94000]: mean loss 0.127165
#   [96000]: mean loss 0.133277
#   [98000]: mean loss 0.12958
#   [100000]: mean loss 0.131104
#   [102000]: mean loss 0.120215
#   [104000]: mean loss 0.123123
#   [106000]: mean loss 0.122113
#   [108000]: mean loss 0.118456
#   [110000]: mean loss 0.11851
#   [112000]: mean loss 0.116154
#   [114000]: mean loss 0.113234
#   [116000]: mean loss 0.10893
#   [118000]: mean loss 0.106758
#   [120000]: mean loss 0.111999
#   [122000]: mean loss 0.119323
#   [124000]: mean loss 0.112955
#   [126000]: mean loss 0.104335
#   [128000]: mean loss 0.0981684
#   [130000]: mean loss 0.117336
#   [132000]: mean loss 0.0962608
#   [134000]: mean loss 0.0968503
#   [136000]: mean loss 0.102598
#   [138000]: mean loss 0.107446
#   [140000]: mean loss 0.0953887
#   [142000]: mean loss 0.0934756
#   [144000]: mean loss 0.0977889
#   [146000]: mean loss 0.094454
#   [148000]: mean loss 0.0902096
#   [150000]: mean loss 0.0929541
#   [152000]: mean loss 0.0970848
#   [154000]: mean loss 0.0870254
#   [156000]: mean loss 0.0908705
#   [158000]: mean loss 0.0875037
#   [160000]: mean loss 0.090136
#   [162000]: mean loss 0.0837596
#   [164000]: mean loss 0.0829208
#   [166000]: mean loss 0.0930467
#   [168000]: mean loss 0.0898942
#   [170000]: mean loss 0.0778942
#   [172000]: mean loss 0.0873987
#   [174000]: mean loss 0.0804612
#   [176000]: mean loss 0.083415
#   [178000]: mean loss 0.076615
#   [180000]: mean loss 0.0763321
#   [182000]: mean loss 0.0792404
#   [184000]: mean loss 0.0802126
#   [186000]: mean loss 0.0853414
#   [188000]: mean loss 0.0770167
#   [190000]: mean loss 0.0729604
#   [192000]: mean loss 0.074165
#   [194000]: mean loss 0.0787026
#   [196000]: mean loss 0.0729542
#   [198000]: mean loss 0.0805191
#   [200000]: mean loss 0.077904
#   [202000]: mean loss 0.0751408
#   [203621]: mean loss 0.0718804
# SGD complete: 203621 examples in 5799.61 seconds.
# running w:5 h:150: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.89529
#   [2000]: mean loss 0.373101
#   [4000]: mean loss 0.360764
#   [6000]: mean loss 0.331237
#   [8000]: mean loss 0.317198
#   [10000]: mean loss 0.305601
#   [12000]: mean loss 0.299444
#   [14000]: mean loss 0.283626
#   [16000]: mean loss 0.277264
#   [18000]: mean loss 0.273257
#   [20000]: mean loss 0.265648
#   [22000]: mean loss 0.270513
#   [24000]: mean loss 0.265554
#   [26000]: mean loss 0.254767
#   [28000]: mean loss 0.244262
#   [30000]: mean loss 0.243379
#   [32000]: mean loss 0.243596
#   [34000]: mean loss 0.245644
#   [36000]: mean loss 0.227517
#   [38000]: mean loss 0.226732
#   [40000]: mean loss 0.241518
#   [42000]: mean loss 0.230303
#   [44000]: mean loss 0.22127
#   [46000]: mean loss 0.219105
#   [48000]: mean loss 0.213374
#   [50000]: mean loss 0.218499
#   [52000]: mean loss 0.217542
#   [54000]: mean loss 0.211572
#   [56000]: mean loss 0.201991
#   [58000]: mean loss 0.201268
#   [60000]: mean loss 0.207993
#   [62000]: mean loss 0.19286
#   [64000]: mean loss 0.197731
#   [66000]: mean loss 0.192697
#   [68000]: mean loss 0.188711
#   [70000]: mean loss 0.191995
#   [72000]: mean loss 0.194985
#   [74000]: mean loss 0.181624
#   [76000]: mean loss 0.191821
#   [78000]: mean loss 0.177302
#   [80000]: mean loss 0.176043
#   [82000]: mean loss 0.175173
#   [84000]: mean loss 0.179518
#   [86000]: mean loss 0.169459
#   [88000]: mean loss 0.172316
#   [90000]: mean loss 0.170249
#   [92000]: mean loss 0.181607
#   [94000]: mean loss 0.163995
#   [96000]: mean loss 0.169335
#   [98000]: mean loss 0.166538
#   [100000]: mean loss 0.167776
#   [102000]: mean loss 0.158777
#   [104000]: mean loss 0.162723
#   [106000]: mean loss 0.162773
#   [108000]: mean loss 0.15933
#   [110000]: mean loss 0.153852
#   [112000]: mean loss 0.154398
#   [114000]: mean loss 0.152775
#   [116000]: mean loss 0.150384
#   [118000]: mean loss 0.147095
#   [120000]: mean loss 0.156446
#   [122000]: mean loss 0.171602
#   [124000]: mean loss 0.148905
#   [126000]: mean loss 0.147576
#   [128000]: mean loss 0.139831
#   [130000]: mean loss 0.14725
#   [132000]: mean loss 0.140396
#   [134000]: mean loss 0.143691
#   [136000]: mean loss 0.141266
#   [138000]: mean loss 0.142613
#   [140000]: mean loss 0.137183
#   [142000]: mean loss 0.141783
#   [144000]: mean loss 0.13886
#   [146000]: mean loss 0.139221
#   [148000]: mean loss 0.132478
# ...
#   [60000]: mean loss 0.163888
#   [62000]: mean loss 0.174897
#   [64000]: mean loss 0.171488
#   [66000]: mean loss 0.165185
#   [68000]: mean loss 0.162164
#   [70000]: mean loss 0.15162
#   [72000]: mean loss 0.149421
#   [74000]: mean loss 0.150798
#   [76000]: mean loss 0.149988
#   [78000]: mean loss 0.141548
#   [80000]: mean loss 0.147758
#   [82000]: mean loss 0.140533
#   [84000]: mean loss 0.137795
#   [86000]: mean loss 0.139083
#   [88000]: mean loss 0.131819
#   [90000]: mean loss 0.141523
#   [92000]: mean loss 0.12946
#   [94000]: mean loss 0.127833
#   [96000]: mean loss 0.131554
#   [98000]: mean loss 0.122183
#   [100000]: mean loss 0.126849
#   [102000]: mean loss 0.122179
#   [104000]: mean loss 0.124488
#   [106000]: mean loss 0.119705
#   [108000]: mean loss 0.116375
#   [110000]: mean loss 0.113281
#   [112000]: mean loss 0.114895
#   [114000]: mean loss 0.117545
#   [116000]: mean loss 0.10964
#   [118000]: mean loss 0.114869
#   [120000]: mean loss 0.106975
#   [122000]: mean loss 0.117064
#   [124000]: mean loss 0.10398
#   [126000]: mean loss 0.103992
#   [128000]: mean loss 0.0995192
#   [130000]: mean loss 0.102436
#   [132000]: mean loss 0.0963955
#   [134000]: mean loss 0.101265
#   [136000]: mean loss 0.099225
#   [138000]: mean loss 0.0957863
#   [140000]: mean loss 0.0931103
#   [142000]: mean loss 0.0930517
#   [144000]: mean loss 0.092819
#   [146000]: mean loss 0.0927414
#   [148000]: mean loss 0.0914799
#   [150000]: mean loss 0.0841821
#   [152000]: mean loss 0.0869905
#   [154000]: mean loss 0.0825054
#   [156000]: mean loss 0.090676
#   [158000]: mean loss 0.0786318
#   [160000]: mean loss 0.0862228
#   [162000]: mean loss 0.0832213
#   [164000]: mean loss 0.0864295
#   [166000]: mean loss 0.0790173
#   [168000]: mean loss 0.0772066
#   [170000]: mean loss 0.0786096
#   [172000]: mean loss 0.0729412
#   [174000]: mean loss 0.0774033
#   [176000]: mean loss 0.0862732
#   [178000]: mean loss 0.0802677
#   [180000]: mean loss 0.0849352
#   [182000]: mean loss 0.0740574
#   [184000]: mean loss 0.0734996
#   [186000]: mean loss 0.0730525
#   [188000]: mean loss 0.0701306
#   [190000]: mean loss 0.0698112
#   [192000]: mean loss 0.0697544
#   [194000]: mean loss 0.0698346
#   [196000]: mean loss 0.0804712
#   [198000]: mean loss 0.0748437
#   [200000]: mean loss 0.0648816
#   [202000]: mean loss 0.0707783
#   [203621]: mean loss 0.0666529
# SGD complete: 203621 examples in 5918.76 seconds.
# running w:7 h:150: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.2702
#   [2000]: mean loss 0.365447
#   [4000]: mean loss 0.345887
#   [6000]: mean loss 0.328031
#   [8000]: mean loss 0.315042
#   [10000]: mean loss 0.303913
#   [12000]: mean loss 0.297778
#   [14000]: mean loss 0.279664
#   [16000]: mean loss 0.283836
#   [18000]: mean loss 0.267253
#   [20000]: mean loss 0.266997
#   [22000]: mean loss 0.265144
#   [24000]: mean loss 0.266145
#   [26000]: mean loss 0.250622
#   [28000]: mean loss 0.252844
#   [30000]: mean loss 0.250712
#   [32000]: mean loss 0.238343
#   [34000]: mean loss 0.230897
#   [36000]: mean loss 0.225189
#   [38000]: mean loss 0.229693
#   [40000]: mean loss 0.21985
#   [42000]: mean loss 0.227992
#   [44000]: mean loss 0.21592
#   [46000]: mean loss 0.222819
#   [48000]: mean loss 0.215158
#   [50000]: mean loss 0.209019
#   [52000]: mean loss 0.213979
#   [54000]: mean loss 0.199945
#   [56000]: mean loss 0.221015
#   [58000]: mean loss 0.1993
#   [60000]: mean loss 0.192494
#   [62000]: mean loss 0.199518
#   [64000]: mean loss 0.209002
#   [66000]: mean loss 0.202039
#   [68000]: mean loss 0.195299
#   [70000]: mean loss 0.183306
#   [72000]: mean loss 0.183291
#   [74000]: mean loss 0.183294
#   [76000]: mean loss 0.177134
#   [78000]: mean loss 0.179354
#   [80000]: mean loss 0.188566
#   [82000]: mean loss 0.17286
#   [84000]: mean loss 0.176288
#   [86000]: mean loss 0.17726
#   [88000]: mean loss 0.173295
#   [90000]: mean loss 0.177585
#   [92000]: mean loss 0.165116
#   [94000]: mean loss 0.168971
#   [96000]: mean loss 0.172125
#   [98000]: mean loss 0.161964
#   [100000]: mean loss 0.169177
#   [102000]: mean loss 0.162534
#   [104000]: mean loss 0.168534
#   [106000]: mean loss 0.158801
#   [108000]: mean loss 0.158655
#   [110000]: mean loss 0.159425
#   [112000]: mean loss 0.16152
#   [114000]: mean loss 0.159602
#   [116000]: mean loss 0.151731
#   [118000]: mean loss 0.165216
#   [120000]: mean loss 0.146311
#   [122000]: mean loss 0.157402
#   [124000]: mean loss 0.145995
#   [126000]: mean loss 0.144768
#   [128000]: mean loss 0.145298
#   [130000]: mean loss 0.149828
#   [132000]: mean loss 0.143883
#   [134000]: mean loss 0.145284
#   [136000]: mean loss 0.14503
#   [138000]: mean loss 0.144885
#   [140000]: mean loss 0.139363
#   [142000]: mean loss 0.133949
#   [144000]: mean loss 0.136166
#   [146000]: mean loss 0.132721
#   [148000]: mean loss 0.135624
#   [150000]: mean loss 0.132083
#   [152000]: mean loss 0.137276
#   [154000]: mean loss 0.131221
#   [156000]: mean loss 0.13489
#   [158000]: mean loss 0.130858
#   [160000]: mean loss 0.130288
#   [162000]: mean loss 0.12918
#   [164000]: mean loss 0.130767
#   [166000]: mean loss 0.125818
#   [168000]: mean loss 0.133652
#   [170000]: mean loss 0.123467
#   [172000]: mean loss 0.123131
#   [174000]: mean loss 0.127183
#   [176000]: mean loss 0.132823
#   [178000]: mean loss 0.129904
#   [180000]: mean loss 0.12706
#   [182000]: mean loss 0.121488
#   [184000]: mean loss 0.119918
#   [186000]: mean loss 0.125992
#   [188000]: mean loss 0.121496
#   [190000]: mean loss 0.116117
#   [192000]: mean loss 0.118144
#   [194000]: mean loss 0.12223
#   [196000]: mean loss 0.129526
#   [198000]: mean loss 0.125047
#   [200000]: mean loss 0.116557
#   [202000]: mean loss 0.113346
#   [203621]: mean loss 0.11555
# SGD complete: 203621 examples in 6361.48 seconds.
# running w:7 h:200: r:0.000000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.57053
#   [2000]: mean loss 0.367737
#   [4000]: mean loss 0.341414
#   [6000]: mean loss 0.355066
#   [8000]: mean loss 0.32112
#   [10000]: mean loss 0.310402
#   [12000]: mean loss 0.305369
#   [14000]: mean loss 0.275553
#   [16000]: mean loss 0.277974
#   [18000]: mean loss 0.283324
#   [20000]: mean loss 0.306127
#   [22000]: mean loss 0.269063
#   [24000]: mean loss 0.240349
#   [26000]: mean loss 0.236251
#   [28000]: mean loss 0.251471
#   [30000]: mean loss 0.218638
#   [32000]: mean loss 0.218901
#   [34000]: mean loss 0.231642
#   [36000]: mean loss 0.213095
#   [38000]: mean loss 0.204352
#   [40000]: mean loss 0.213558
#   [42000]: mean loss 0.197502
#   [44000]: mean loss 0.197035
#   [46000]: mean loss 0.199984
#   [48000]: mean loss 0.191527
#   [50000]: mean loss 0.192428
#   [52000]: mean loss 0.175034
#   [54000]: mean loss 0.183961
#   [56000]: mean loss 0.189947
#   [58000]: mean loss 0.171682
#   [60000]: mean loss 0.165777
#   [62000]: mean loss 0.160743
#   [64000]: mean loss 0.160242
#   [66000]: mean loss 0.15607
#   [68000]: mean loss 0.151732
#   [70000]: mean loss 0.176558
#   [72000]: mean loss 0.149632
#   [74000]: mean loss 0.146346
#   [76000]: mean loss 0.140077
#   [78000]: mean loss 0.138876
#   [80000]: mean loss 0.134352
#   [82000]: mean loss 0.144092
#   [84000]: mean loss 0.130561
#   [86000]: mean loss 0.132593
#   [88000]: mean loss 0.127696
#   [90000]: mean loss 0.13653
#   [92000]: mean loss 0.139724
#   [94000]: mean loss 0.120222
#   [96000]: mean loss 0.123293
#   [98000]: mean loss 0.118535
#   [100000]: mean loss 0.130226
#   [102000]: mean loss 0.124436
#   [104000]: mean loss 0.124597
#   [106000]: mean loss 0.111068
#   [108000]: mean loss 0.116493
#   [110000]: mean loss 0.106922
#   [112000]: mean loss 0.107562
#   [114000]: mean loss 0.11031
#   [116000]: mean loss 0.105446
#   [118000]: mean loss 0.101988
#   [120000]: mean loss 0.0964048
#   [122000]: mean loss 0.0973903
#   [124000]: mean loss 0.0981869
#   [126000]: mean loss 0.101887
#   [128000]: mean loss 0.0978857
#   [130000]: mean loss 0.0887162
#   [132000]: mean loss 0.0904682
#   [134000]: mean loss 0.0910852
#   [136000]: mean loss 0.0914097
#   [138000]: mean loss 0.0897759
#   [140000]: mean loss 0.0857317
#   [142000]: mean loss 0.085557
#   [144000]: mean loss 0.0822811
#   [146000]: mean loss 0.0937598
#   [148000]: mean loss 0.0854414
#   [150000]: mean loss 0.0777752
#   [152000]: mean loss 0.0805632
#   [154000]: mean loss 0.0781215
#   [156000]: mean loss 0.0839087
#   [158000]: mean loss 0.0742956
#   [160000]: mean loss 0.0725726
#   [162000]: mean loss 0.0743719
#   [164000]: mean loss 0.0785232
#   [166000]: mean loss 0.0723876
#   [168000]: mean loss 0.0683706
#   [170000]: mean loss 0.0669102
#   [172000]: mean loss 0.06657
#   [174000]: mean loss 0.0709266
#   [176000]: mean loss 0.0661151
#   [178000]: mean loss 0.0648778
#   [180000]: mean loss 0.0618508
#   [182000]: mean loss 0.0743333
#   [184000]: mean loss 0.067017
#   [186000]: mean loss 0.0637147
#   [188000]: mean loss 0.0655206
#   [190000]: mean loss 0.0669087
#   [192000]: mean loss 0.0621399
#   [194000]: mean loss 0.0594992
#   [196000]: mean loss 0.0634939
#   [198000]: mean loss 0.0557943
#   [200000]: mean loss 0.06052
#   [202000]: mean loss 0.057971
#   [203621]: mean loss 0.0563716
# SGD complete: 203621 examples in 11830.06 seconds.
# running w:7 h:200: r:0.000100...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.57053
#   [2000]: mean loss 0.367627
#   [4000]: mean loss 0.3414
#   [6000]: mean loss 0.354429
#   [8000]: mean loss 0.321016
#   [10000]: mean loss 0.310097
#   [12000]: mean loss 0.30532
#   [14000]: mean loss 0.276528
#   [16000]: mean loss 0.278648
#   [18000]: mean loss 0.279891
#   [20000]: mean loss 0.308644
#   [22000]: mean loss 0.268086
#   [24000]: mean loss 0.241932
#   [26000]: mean loss 0.23739
#   [28000]: mean loss 0.251306
#   [30000]: mean loss 0.219644
#   [32000]: mean loss 0.219133
#   [34000]: mean loss 0.231798
#   [36000]: mean loss 0.214252
#   [38000]: mean loss 0.204664
#   [40000]: mean loss 0.215147
#   [42000]: mean loss 0.199794
#   [44000]: mean loss 0.198028
#   [46000]: mean loss 0.203604
#   [48000]: mean loss 0.193515
#   [50000]: mean loss 0.192802
#   [52000]: mean loss 0.178368
#   [54000]: mean loss 0.186351
#   [56000]: mean loss 0.19277
#   [58000]: mean loss 0.171303
#   [60000]: mean loss 0.169016
#   [62000]: mean loss 0.164515
#   [64000]: mean loss 0.163033
#   [66000]: mean loss 0.160161
#   [68000]: mean loss 0.155744
#   [70000]: mean loss 0.177222
#   [72000]: mean loss 0.158156
#   [74000]: mean loss 0.151291
#   [76000]: mean loss 0.14525
#   [78000]: mean loss 0.143957
#   [80000]: mean loss 0.139638
#   [82000]: mean loss 0.147258
#   [84000]: mean loss 0.134796
#   [86000]: mean loss 0.136231
#   [88000]: mean loss 0.133418
#   [90000]: mean loss 0.139257
#   [92000]: mean loss 0.142132
#   [94000]: mean loss 0.125861
#   [96000]: mean loss 0.128184
#   [98000]: mean loss 0.123663
#   [100000]: mean loss 0.133328
#   [102000]: mean loss 0.129559
#   [104000]: mean loss 0.127077
#   [106000]: mean loss 0.117794
#   [108000]: mean loss 0.127803
#   [110000]: mean loss 0.114717
#   [112000]: mean loss 0.116439
#   [114000]: mean loss 0.114616
#   [116000]: mean loss 0.110793
#   [118000]: mean loss 0.108909
#   [120000]: mean loss 0.103973
#   [122000]: mean loss 0.103465
#   [124000]: mean loss 0.107779
#   [126000]: mean loss 0.110504
#   [128000]: mean loss 0.107129
#   [130000]: mean loss 0.096403
#   [132000]: mean loss 0.0977753
#   [134000]: mean loss 0.102375
#   [136000]: mean loss 0.0998207
#   [138000]: mean loss 0.0971571
#   [140000]: mean loss 0.095256
#   [142000]: mean loss 0.0928677
#   [144000]: mean loss 0.0920027
#   [146000]: mean loss 0.102592
#   [148000]: mean loss 0.0934297
#   [150000]: mean loss 0.0857466
#   [152000]: mean loss 0.0859322
#   [154000]: mean loss 0.0870894
#   [156000]: mean loss 0.0904917
#   [158000]: mean loss 0.0847986
#   [160000]: mean loss 0.0820346
#   [162000]: mean loss 0.0826154
#   [164000]: mean loss 0.0879632
#   [166000]: mean loss 0.0822946
#   [168000]: mean loss 0.0763098
#   [170000]: mean loss 0.0779357
#   [172000]: mean loss 0.0762234
#   [174000]: mean loss 0.0806975
#   [176000]: mean loss 0.0785076
#   [178000]: mean loss 0.0758529
#   [180000]: mean loss 0.0720301
#   [182000]: mean loss 0.0789974
#   [184000]: mean loss 0.0821826
#   [186000]: mean loss 0.0739492
#   [188000]: mean loss 0.0718684
#   [190000]: mean loss 0.0752701
#   [192000]: mean loss 0.0697113
#   [194000]: mean loss 0.070005
#   [196000]: mean loss 0.0704759
#   [198000]: mean loss 0.0671475
#   [200000]: mean loss 0.0711576
#   [202000]: mean loss 0.0718888
#   [203621]: mean loss 0.0682239
# SGD complete: 203621 examples in 6075.20 seconds.
# running w:7 h:200: r:0.001000...
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 1.57053
#   [2000]: mean loss 0.366898
#   [4000]: mean loss 0.341984
#   [6000]: mean loss 0.350634
#   [8000]: mean loss 0.322852
#   [10000]: mean loss 0.316315
#   [12000]: mean loss 0.304623
#   [14000]: mean loss 0.283441
#   [16000]: mean loss 0.284689
#   [18000]: mean loss 0.284382
#   [20000]: mean loss 0.317194
#   [22000]: mean loss 0.275431
#   [24000]: mean loss 0.252946
#   [26000]: mean loss 0.251252
#   [28000]: mean loss 0.264582
#   [30000]: mean loss 0.235565
#   [32000]: mean loss 0.236253
#   [34000]: mean loss 0.244363
#   [36000]: mean loss 0.235933
#   [38000]: mean loss 0.230377
#   [40000]: mean loss 0.244502
#   [42000]: mean loss 0.219401
#   [44000]: mean loss 0.218951
#   [46000]: mean loss 0.227542
#   [48000]: mean loss 0.218638
#   [50000]: mean loss 0.215914
#   [52000]: mean loss 0.208542
#   [54000]: mean loss 0.209227
#   [56000]: mean loss 0.216475
#   [58000]: mean loss 0.200475
#   [60000]: mean loss 0.200675
#   [62000]: mean loss 0.197392
#   [64000]: mean loss 0.191896
#   [66000]: mean loss 0.19105
#   [68000]: mean loss 0.186659
#   [70000]: mean loss 0.193317
#   [72000]: mean loss 0.191204
#   [74000]: mean loss 0.185901
#   [76000]: mean loss 0.183047
#   [78000]: mean loss 0.181311
#   [80000]: mean loss 0.178533
#   [82000]: mean loss 0.182396
#   [84000]: mean loss 0.172304
#   [86000]: mean loss 0.173481
#   [88000]: mean loss 0.170443
#   [90000]: mean loss 0.175626
#   [92000]: mean loss 0.179998
#   [94000]: mean loss 0.170674
#   [96000]: mean loss 0.164164
#   [98000]: mean loss 0.162178
#   [100000]: mean loss 0.175835
#   [102000]: mean loss 0.166026
#   [104000]: mean loss 0.162872
#   [106000]: mean loss 0.158454
#   [108000]: mean loss 0.177569
#   [110000]: mean loss 0.153344
#   [112000]: mean loss 0.160793
#   [114000]: mean loss 0.154717
#   [116000]: mean loss 0.157696
#   [118000]: mean loss 0.147786
#   [120000]: mean loss 0.147765
#   [122000]: mean loss 0.144208
#   [124000]: mean loss 0.151297
#   [126000]: mean loss 0.149125
#   [128000]: mean loss 0.145566
#   [130000]: mean loss 0.13665
#   [132000]: mean loss 0.14287
#   [134000]: mean loss 0.145085
#   [136000]: mean loss 0.142412
#   [138000]: mean loss 0.136225
#   [140000]: mean loss 0.137511
#   [142000]: mean loss 0.136121
#   [144000]: mean loss 0.134127
#   [146000]: mean loss 0.142949
#   [148000]: mean loss 0.133747
#   [150000]: mean loss 0.134534
#   [152000]: mean loss 0.134284
#   [154000]: mean loss 0.133674
#   [156000]: mean loss 0.135009
#   [158000]: mean loss 0.130783
#   [160000]: mean loss 0.129571
#   [162000]: mean loss 0.130292
#   [164000]: mean loss 0.126812
#   [166000]: mean loss 0.128663
#   [168000]: mean loss 0.131969
#   [170000]: mean loss 0.126246
#   [172000]: mean loss 0.125756
#   [174000]: mean loss 0.129408
#   [176000]: mean loss 0.127683
#   [178000]: mean loss 0.123368
#   [180000]: mean loss 0.117046
#   [182000]: mean loss 0.123502
#   [184000]: mean loss 0.130698
#   [186000]: mean loss 0.119885
#   [188000]: mean loss 0.11734
#   [190000]: mean loss 0.119105
#   [192000]: mean loss 0.115627
#   [194000]: mean loss 0.119499
#   [196000]: mean loss 0.117014
#   [198000]: mean loss 0.114491
#   [200000]: mean loss 0.121249
#   [202000]: mean loss 0.116368
#   [203621]: mean loss 0.112912
# SGD complete: 203621 examples in 6302.50 seconds.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-68c8334f1080> in <module>()
#      39     X_dev_w, y_dev_w = du.docs_to_windows(docs_dev, word_to_num, tag_to_num, wsize=model.windowsize)
#      40     yp = model.predict(X_dev_w)
# ---> 41     f1 = eval_performance(y_dev_w, yp, tagnames)
#      42     desc = 'window size: %d; hidden units: %d, regularization %f -- f1 %.02f' % (model.windowsize, model.hidden_units, model.lreg, f1)
#      43     if f1 > bestF1:
#
# NameError: name 'eval_performance' is not defined

# %%
from nerwindow import eval_performance
traincurvebest = 0
bestF1 = 0
best = ''
bestModel = 0
for i in xrange(0, len(clfs)):
    model = clfs[i]
    X_dev_w, y_dev_w = du.docs_to_windows(docs_dev, word_to_num, tag_to_num, wsize=model.windowsize)
    yp = model.predict(X_dev_w)
    desc = 'window size: %d; hidden units: %d, regularization %f -- f1 %.02f' % (model.windowsize, model.hidden_units, model.lreg, f1)
    print desc
    f1 = eval_performance(y_dev_w, yp, tagnames)
    if f1 > bestF1:
        bestF1 = f1
        traincurvebest = traincurves[i]
        best = desc
        bestModel = clf
print 'best is ' + best
# Out:
# === Performance (omitting 'O' class) ===
# Mean precision:  84.55%
# Mean recall:     75.53%
# Mean F1:         79.72%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.80%
# Mean recall:     75.07%
# Mean F1:         79.59%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.55%
# Mean recall:     72.85%
# Mean F1:         78.19%
# === Performance (omitting 'O' class) ===
# Mean precision:  83.10%
# Mean recall:     76.98%
# Mean F1:         79.90%
# === Performance (omitting 'O' class) ===
# Mean precision:  82.99%
# Mean recall:     76.85%
# Mean F1:         79.77%
# === Performance (omitting 'O' class) ===
# Mean precision:  82.60%
# Mean recall:     72.58%
# Mean F1:         77.15%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.44%
# Mean recall:     77.80%
# Mean F1:         80.86%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.22%
# Mean recall:     77.08%
# Mean F1:         80.38%
# === Performance (omitting 'O' class) ===
# Mean precision:  83.84%
# Mean recall:     71.89%
# Mean F1:         77.10%
# === Performance (omitting 'O' class) ===
# Mean precision:  86.39%
# Mean recall:     77.14%
# Mean F1:         81.47%
# === Performance (omitting 'O' class) ===
# Mean precision:  85.48%
# Mean recall:     77.23%
# Mean F1:         81.05%
# === Performance (omitting 'O' class) ===
# Mean precision:  83.54%
# Mean recall:     73.10%
# Mean F1:         77.69%
# === Performance (omitting 'O' class) ===
# Mean precision:  85.90%
# Mean recall:     77.26%
# Mean F1:         81.34%
# === Performance (omitting 'O' class) ===
# Mean precision:  86.41%
# Mean recall:     76.87%
# Mean F1:         81.34%
# === Performance (omitting 'O' class) ===
# Mean precision:  83.79%
# Mean recall:     74.89%
# Mean F1:         79.04%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.34%
# Mean recall:     79.70%
# Mean F1:         81.92%
# === Performance (omitting 'O' class) ===
# Mean precision:  83.61%
# Mean recall:     80.13%
# Mean F1:         81.72%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.51%
# Mean recall:     75.47%
# Mean F1:         79.52%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.81%
# Mean recall:     78.83%
# Mean F1:         81.55%
# === Performance (omitting 'O' class) ===
# Mean precision:  85.23%
# Mean recall:     78.73%
# Mean F1:         81.72%
# === Performance (omitting 'O' class) ===
# Mean precision:  81.84%
# Mean recall:     77.35%
# Mean F1:         79.32%
# === Performance (omitting 'O' class) ===
# Mean precision:  83.52%
# Mean recall:     77.28%
# Mean F1:         80.26%
# === Performance (omitting 'O' class) ===
# Mean precision:  82.84%
# Mean recall:     78.86%
# Mean F1:         80.78%
# === Performance (omitting 'O' class) ===
# Mean precision:  81.19%
# Mean recall:     75.86%
# Mean F1:         78.38%
# === Performance (omitting 'O' class) ===
# Mean precision:  85.52%
# Mean recall:     79.16%
# Mean F1:         82.14%
# === Performance (omitting 'O' class) ===
# Mean precision:  85.17%
# Mean recall:     78.62%
# Mean F1:         81.64%
# === Performance (omitting 'O' class) ===
# Mean precision:  84.84%
# Mean recall:     75.60%
# Mean F1:         79.62%
# best is window size: 7; hidden units: 200, regularization 0.000000 -- f1 82.14

# %%
idxiter = rand_sched()
idxiter = mb_rand_sched(50000)
clf = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
                reg=0.001, alpha=0.01)

traincurve1 = clf.train_sgd(X_train, y_train, idxiter, printevery=10000/k, costevery=200)
clf = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
                reg=0.001, alpha=0.1)

traincurve2 = clf.train_sgd(X_train, y_train, idxiter, printevery=10000/k, costevery=200)
# Out:
#              precision    recall  f1-score   support
#
#           O       0.97      0.99      0.98     42759
#         LOC       0.91      0.80      0.85      2094
#        MISC       0.80      0.74      0.76      1268
#         ORG       0.71      0.67      0.69      2092
#         PER       0.92      0.77      0.84      3149
#
# avg / total       0.95      0.95      0.95     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  84.80%
# Mean recall:     75.07%
# Mean F1:         79.59%
# 0.0906072208071

# %%
#### YOUR CODE HERE ####
# Sandbox: build a good model by tuning hyperparameters
counts, costs = zip(*traincurvebest)
figure(figsize=(6,4))
plot(k*array(counts), costs, color='b', marker='o', linestyle='-')
title(r"Learning Curve (batch size=%d, window=%d, hidden=%d, $\alpha$=%g, $\lambda$=%g)" % (k, bestModel.windowsize, bestModel.hidden_units, bestModel.alpha, bestModel.lreg))
xlabel("SGD Iterations"); ylabel(r"Average $J(\theta)$"); 
ylim(ymin=0, ymax=max(1.1*max(costs),3*min(costs)));
ylim(0,0.5)

#### END YOUR CODE ####
# Out:
# (0, 0.5)

# %% [markdown]
# ## (e): Plot Learning Curves
# The `train_sgd` function returns a list of points `(counter, cost)` giving the mean loss after that number of SGD iterations.
#
# If the model is taking too long you can cut it off by going to *Kernel->Interrupt* in the IPython menu; `train_sgd` will return the training curve so-far, and you can restart without losing your training progress.
#
# Make two plots:
#
# - Learning curve using `reg = 0.001`, and comparing the effect of changing the learning rate: run with `alpha = 0.01` and `alpha = 0.1`. Use minibatches of size 5, and train for 10,000 minibatches with `costevery=200`. Be sure to scale up your counts (x-axis) to reflect the batch size. What happens if the model tries to learn too fast? Explain why this occurs, based on the relation of SGD to the true objective.
#
# - Learning curve for your best model (print the hyperparameters in the title), as trained using your best schedule. Set `costevery` so that you get at least 100 points to plot.

# %%
##
# Plot your best learning curve here
counts, costs = zip(*traincurvebest)
figure(figsize=(6,4))
plot(5*array(counts), costs, color='b', marker='o', linestyle='-')
title(r"Learning Curve ($\alpha$=%g, $\lambda$=%g)" % (bestModel.alpha, bestModel.lreg))
xlabel("SGD Iterations"); ylabel(r"Average $J(\theta)$"); 
ylim(ymin=0, ymax=max(1.1*max(costs),3*min(costs)));
ylim(0,0.5)

# Don't change this filename!
savefig("ner.learningcurve.best.png")

# %%
idxiter = mb_rand_sched(50000)
clf2 = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
                 reg=0.001, alpha=0.01)

traincurve1 = clf2.train_sgd(X_train, y_train, idxiter, printevery=10000/k, costevery=200)

idxiter = mb_rand_sched(50000)
clf2 = WindowMLP(wv, windowsize=windowsize, dims=[None, 100, 5],
                reg=0.001, alpha=0.1)

traincurve2 = clf2.train_sgd(X_train, y_train, idxiter, printevery=10000/k, costevery=200)
# Out:
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.15814
#   [200]: mean loss 0.463111
#   [400]: mean loss 0.437412
#   [600]: mean loss 0.410703
#   [800]: mean loss 0.408835
#   [1000]: mean loss 0.401784
#   [1200]: mean loss 0.406812
#   [1400]: mean loss 0.4039
#   [1600]: mean loss 0.385686
#   [1800]: mean loss 0.369568
#   Seen 2000 in 147.05 s
#   [2000]: mean loss 0.371176
#   [2200]: mean loss 0.378317
#   [2400]: mean loss 0.363936
#   [2600]: mean loss 0.366125
#   [2800]: mean loss 0.361043
#   [3000]: mean loss 0.359564
#   [3200]: mean loss 0.354854
#   [3400]: mean loss 0.356216
#   [3600]: mean loss 0.351883
#   [3800]: mean loss 0.347918
#   Seen 4000 in 295.35 s
#   [4000]: mean loss 0.356678
#   [4200]: mean loss 0.35007
#   [4400]: mean loss 0.353136
#   [4600]: mean loss 0.339424
#   [4800]: mean loss 0.339787
#   [5000]: mean loss 0.343788
#   [5200]: mean loss 0.335379
#   [5400]: mean loss 0.33403
#   [5600]: mean loss 0.340354
#   [5800]: mean loss 0.332719
#   Seen 6000 in 445.17 s
#   [6000]: mean loss 0.3341
#   [6200]: mean loss 0.332266
#   [6400]: mean loss 0.330902
#   [6600]: mean loss 0.330828
#   [6800]: mean loss 0.333617
#   [7000]: mean loss 0.336581
#   [7200]: mean loss 0.329283
#   [7400]: mean loss 0.339134
#   [7600]: mean loss 0.320575
#   [7800]: mean loss 0.328295
#   Seen 8000 in 592.17 s
#   [8000]: mean loss 0.326956
#   [8200]: mean loss 0.330194
#   [8400]: mean loss 0.319597
#   [8600]: mean loss 0.326231
#   [8800]: mean loss 0.320225
#   [9000]: mean loss 0.328282
#   [9200]: mean loss 0.323359
#   [9400]: mean loss 0.317957
#   [9600]: mean loss 0.319679
#   [9800]: mean loss 0.323024
#   [10000]: mean loss 0.313784
# SGD complete: 10000 examples in 747.44 seconds.
# Begin SGD...
#   Seen 0 in 0.02 s
#   [0]: mean loss 2.15814
#   [200]: mean loss 0.968708
#   [400]: mean loss 0.96921
#   [600]: mean loss 0.864782
#   [800]: mean loss 0.735158
#   [1000]: mean loss 0.75514
#   [1200]: mean loss 0.783252
#   [1400]: mean loss 0.786663
#   [1600]: mean loss 1.11779
#   [1800]: mean loss 0.898764
#   Seen 2000 in 143.95 s
#   [2000]: mean loss 1.01515
#   [2200]: mean loss 0.895183
#   [2400]: mean loss 0.787052
#   [2600]: mean loss 0.964151
#   [2800]: mean loss 0.889536
#   [3000]: mean loss 0.854917
#   [3200]: mean loss 1.1368
#   [3400]: mean loss 1.16356
#   [3600]: mean loss 0.805651
#   [3800]: mean loss 0.890459
#   Seen 4000 in 287.88 s
#   [4000]: mean loss 0.812699
#   [4200]: mean loss 2.14557
#   [4400]: mean loss 0.854287
#   [4600]: mean loss 0.756417
#   [4800]: mean loss 0.784115
#   [5000]: mean loss 1.09512
#   [5200]: mean loss 0.701566
#   [5400]: mean loss 1.04933
#   [5600]: mean loss 0.792439
#   [5800]: mean loss 0.964657
#   Seen 6000 in 432.85 s
#   [6000]: mean loss 0.843069
#   [6200]: mean loss 0.9677
#   [6400]: mean loss 0.845496
#   [6600]: mean loss 0.732191
#   [6800]: mean loss 1.09716
#   [7000]: mean loss 1.12752
#   [7200]: mean loss 0.897933
#   [7400]: mean loss 1.30414
#   [7600]: mean loss 0.803062
#   [7800]: mean loss 0.929681
#   Seen 8000 in 577.40 s
#   [8000]: mean loss 0.787313
#   [8200]: mean loss 0.788733
#   [8400]: mean loss 0.869596
#   [8600]: mean loss 1.22052
#   [8800]: mean loss 0.81486
#   [9000]: mean loss 0.967659
#   [9200]: mean loss 0.784161
#   [9400]: mean loss 0.707199
#   [9600]: mean loss 0.798869
#   [9800]: mean loss 0.970869
#   [10000]: mean loss 0.997461
# SGD complete: 10000 examples in 732.97 seconds.

# %%
##
# Plot comparison of learning rates here
# feel free to change the code below

figure(figsize=(6,4))
counts, costs = zip(*traincurve1)
plot(k*array(counts), costs, color='b', marker='o', linestyle='-', label=r"$\alpha=0.01$")
counts, costs = zip(*traincurve2)
plot(k*array(counts), costs, color='g', marker='o', linestyle='-', label=r"$\alpha=0.1$")
title(r"Learning Curve ($\lambda=0.01$, minibatch k=5)")
xlabel("SGD Iterations"); ylabel(r"Average $J(\theta)$"); 
ylim(ymin=0, ymax=max(1.1*max(costs),3*min(costs)));
legend()

# Don't change this filename
savefig("ner.learningcurve.comparison.png")

# %% [markdown]
# ## (f): Evaluating your model
# Evaluate the model on the dev set using your `predict` function, and compute performance metrics below!

# %%
# Predict labels on the dev set
X_dev, y_dev = du.docs_to_windows(docs_dev, word_to_num, tag_to_num, wsize=bestModel.windowsize)

yp = clf.predict(X_dev)
# Save predictions to a file, one per line
ner.save_predictions(yp, "dev.predicted")

# %%
from nerwindow import full_report, eval_performance
full_report(y_dev, yp, tagnames) # full report, helpful diagnostics
eval_performance(y_dev, yp, tagnames) # performance: optimize this F1
# Out:
#              precision    recall  f1-score   support
#
#           O       0.97      0.99      0.98     42759
#         LOC       0.89      0.85      0.87      2094
#        MISC       0.84      0.71      0.77      1268
#         ORG       0.77      0.67      0.72      2092
#         PER       0.89      0.87      0.88      3149
#
# avg / total       0.95      0.95      0.95     51362
#
# === Performance (omitting 'O' class) ===
# Mean precision:  85.52%
# Mean recall:     79.16%
# Mean F1:         82.14%
# 82.143691576850699

# %%
# Save your predictions on the test set for us to evaluate
# IMPORTANT: make sure X_test is exactly as loaded 
# from du.docs_to_windows, so that your predictions 
# line up with ours.
yptest = clf.predict(X_test)
ner.save_predictions(yptest, "test.predicted")

# %% [markdown]
# ## Part [1.1]: Probing neuron responses
#
# You might have seen some results from computer vision where the individual neurons learn to detect edges, shapes, or even [cat faces](http://googleblog.blogspot.com/2012/06/using-large-scale-brain-simulations-for.html). We're going to do the same for language.
#
# Recall that each "neuron" is essentially a logistic regression unit, with weights corresponding to rows of the corresponding matrix. So, if we have a hidden layer of dimension 100, then we can think of our matrix $W \in \mathbb{R}^{100 x 150}$ as representing 100 hidden neurons each with weights `W[i,:]` and bias `b1[i]`.
#
# ### (a): Hidden Layer, Center Word
# For now, let's just look at the center word, and ignore the rest of the window. This corresponds to columns `W[:,50:100]`, although this could change if you altered the window size for your model. For each neuron, find the top 10 words that it responds to, as measured by the dot product between `W[i,50:100]` and `L[j]`. Use the provided code to print these words and their scores for 5 neurons of your choice. In your writeup, briefly describe what you notice here.
#
# The `num_to_word` dictionary, loaded earlier, may be helpful.

# %%
# Recommended function to print scores
# scores = list of float
# words = list of str
def print_scores(scores, words):
    for i in range(len(scores)):
        print "[%d]: (%.03f) %s" % (i, scores[i], words[i])

#### YOUR CODE HERE ####
import heapq

print bestModel.params.W1.shape
W1 = bestModel.params.W1
    
neurons = [1,3,4,6,8] # change this to your chosen neurons

for i in neurons:
    best = []
    for l in xrange(0, len(bestModel.sparams.L)):
        centerCols = W1[i,150:200]
        response = dot(centerCols, bestModel.sparams.L[l])
        heapq.heappush(best, (response, num_to_word[l]))
        if len(best) > 10:
           heapq.heappop(best)
    
    topscores, topwords = zip(*best)
    print "Neuron %d" % i
    print_scores(topscores, topwords)
    
#### END YOUR CODE ####
# Out:
# (200, 350)
# Neuron 1
# [0]: (1.812) broadcast
# [1]: (1.844) &
# [2]: (1.874) finance
# [3]: (1.858) transport
# [4]: (1.863) supplement
# [5]: (1.913) sell
# [6]: (2.031) produce
# [7]: (2.209) supply
# [8]: (1.951) earn
# [9]: (2.152) prepare
# Neuron 3
# [0]: (1.279) york
# [1]: (1.293) baltimore
# [2]: (1.290) pierce
# [3]: (1.304) detroit
# [4]: (1.297) holiness
# [5]: (1.334) bury
# [6]: (1.463) elm
# [7]: (1.431) occult
# [8]: (1.429) indiana
# [9]: (1.334) maple
# Neuron 4
# [0]: (5.193) terms
# [1]: (5.296) number
# [2]: (5.246) areas
# [3]: (5.345) course
# [4]: (5.463) difficulties
# [5]: (5.915) conditions
# [6]: (5.287) how
# [7]: (5.502) what
# [8]: (5.491) problems
# [9]: (6.550) purposes
# Neuron 6
# [0]: (0.876) error
# [1]: (0.886) none
# [2]: (0.917) estimated
# [3]: (0.887) coverage
# [4]: (0.902) scores
# [5]: (1.067) missed
# [6]: (1.034) hearing
# [7]: (1.147) incorrect
# [8]: (0.906) denied
# [9]: (1.020) drew
# Neuron 8
# [0]: (0.939) centers
# [1]: (0.948) typically
# [2]: (0.965) regions
# [3]: (0.998) and/or
# [4]: (0.966) roughly
# [5]: (1.122) least
# [6]: (0.969) locations
# [7]: (1.148) (
# [8]: (1.020) asia
# [9]: (1.220) approximately

# %% [markdown]
# ### (b): Model Output, Center Word
# Now, let's do the same for the output layer. Here we only have 5 neurons, one for each class. `O` isn't very interesting, but let's look at the other four.
#
# Here things get a little more complicated: since we take a softmax, we can't just look at the neurons separately. An input could cause several of these neurons to all have a strong response, so we really need to compute the softmax output and find the strongest inputs for each class.
#
# As before, let's consider only the center word (`W[:,50:100]`). For each class `ORG`, `PER`, `LOC`, and `MISC`, find the input words that give the highest probability $P(\text{class}\ |\ \text{word})$.
#
# You'll need to do the full feed-forward computation here - for efficiency, try to express this as a matrix operation on $L$. This is the same feed-forward computation as used to predict probabilities, just with $W$ replaced by `W[:,50:100]`.
#
# As with the hidden-layer neurons, print the top 10 words and their corresponding class probabilities for each class.

# %%
#### YOUR CODE HERE ####


for i in range(1,5):
    print "Output neuron %d: %s" % (i, num_to_tag[i])
    print_scores(topscores[i], topwords[i])
    print ""

#### END YOUR CODE ####

# %% [markdown]
# ### (c): Model Output, Preceding Word
# Now for one final task: let's look at the preceding word. Repeat the above analysis for the output layer, but use the first part of $W$, i.e. `W[:,:50]`.
#
# Describe what you see, and include these results in your writeup.

# %%
#### YOUR CODE HERE ####


for i in range(1,5):
    print "Output neuron %d: %s" % (i, num_to_tag[i])
    print_scores(topscores[i], topwords[i])
    print ""

#### END YOUR CODE ####
